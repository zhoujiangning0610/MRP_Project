# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score,confusion_matrix
import tensorflow as tf
from tensorflow.python.keras.layers import Dense, Dropout, LSTM
from tensorflow.python.keras import Sequential
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,f1_score,accuracy_score

# %%
house_data = pd.read_excel("Clean_Data.xlsx")
house_data
# Out:
#             Date      Time             DateTime System Setting   System Mode  \
# 0     2020-12-10  12:50:00  2020/12/10 12:50:00           heat       heatOff
# 1     2020-12-10  12:55:00  2020/12/10 12:55:00           heat       heatOff
# 2     2020-12-10  13:00:00  2020/12/10 13:00:00           heat       heatOff
# 3     2020-12-10  13:05:00  2020/12/10 13:05:00           heat       heatOff
# 4     2020-12-10  13:10:00  2020/12/10 13:10:00           heat  heatStage1On
# ...          ...       ...                  ...            ...           ...
# 29671 2021-03-23  14:25:00   2021/3/23 14:25:00           heat       heatOff
# 29672 2021-03-23  14:30:00   2021/3/23 14:30:00           heat       heatOff
# 29673 2021-03-23  14:35:00   2021/3/23 14:35:00           heat       heatOff
# 29674 2021-03-23  14:40:00   2021/3/23 14:40:00           heat       heatOff
# 29675 2021-03-23  14:45:00   2021/3/23 14:45:00           heat       heatOff
#
#       Calendar Event Program Mode  Cool Set Temp (C)  Heat Set Temp (C)  \
# 0               auto         Home               21.0               21.0
# 1               auto         Home               21.0               21.0
# 2               auto         Home               21.0               21.0
# 3               auto         Home               21.0               21.0
# 4               auto         Home               21.0               21.0
# ...              ...          ...                ...                ...
# 29671            NaN         Home               21.0               21.0
# 29672            NaN         Home               21.0               21.0
# 29673            NaN         Home               21.0               21.0
# 29674            NaN         Home               21.0               21.0
# 29675            NaN         Home               21.0               21.0
#
#        Current Temp (C)  ...  Thermostat Humidity (%RH)  Thermostat Motion  \
# 0                  21.3  ...                       30.0                1.0
# 1                  21.1  ...                       32.0                1.0
# 2                  20.9  ...                       32.0                0.0
# 3                  20.7  ...                       33.0                0.0
# 4                  20.6  ...                       33.0                1.0
# ...                 ...  ...                        ...                ...
# 29671              21.2  ...                       21.0                0.0
# 29672              21.1  ...                       21.0                0.0
# 29673              21.1  ...                       21.0                0.0
# 29674              21.1  ...                       21.0                0.0
# 29675              21.1  ...                       21.0                1.0
#
#        Bedroom (C)  Bedroom2  3rd floor landing (C)  3rd floor landing2  \
# 0             21.6       0.0                   20.9                 0.0
# 1             21.6       0.0                   20.9                 0.0
# 2             21.6       0.0                   20.8                 0.0
# 3             21.6       0.0                   20.8                 0.0
# 4             21.6       0.0                   20.8                 0.0
# ...            ...       ...                    ...                 ...
# 29671         21.9       0.0                   21.8                 0.0
# 29672         21.9       0.0                   21.8                 0.0
# 29673         21.9       0.0                   21.8                 1.0
# 29674         21.9       0.0                   21.8                 1.0
# 29675         21.9       0.0                   21.8                 0.0
#
#        3rd floor room (C)  3rd floor room2  Basement (C)  Basement2
# 0                    21.0              0.0          22.8        0.0
# 1                    20.9              0.0          22.7        1.0
# 2                    20.8              0.0          22.7        1.0
# 3                    20.8              0.0          22.8        0.0
# 4                    20.8              0.0          22.8        0.0
# ...                   ...              ...           ...        ...
# 29671                21.3              0.0          22.0        1.0
# 29672                21.3              0.0          22.1        0.0
# 29673                21.3              0.0          22.1        0.0
# 29674                21.3              0.0          22.1        0.0
# 29675                21.3              0.0          22.1        1.0
#
# [29676 rows x 27 columns]

# %%
house_data["Heat Stage 1 (min)"] = house_data["Heat Stage 1 (sec)"]/60
house_data
# Out:
#             Date      Time             DateTime System Setting   System Mode  \
# 0     2020-12-10  12:50:00  2020/12/10 12:50:00           heat       heatOff
# 1     2020-12-10  12:55:00  2020/12/10 12:55:00           heat       heatOff
# 2     2020-12-10  13:00:00  2020/12/10 13:00:00           heat       heatOff
# 3     2020-12-10  13:05:00  2020/12/10 13:05:00           heat       heatOff
# 4     2020-12-10  13:10:00  2020/12/10 13:10:00           heat  heatStage1On
# ...          ...       ...                  ...            ...           ...
# 29671 2021-03-23  14:25:00   2021/3/23 14:25:00           heat       heatOff
# 29672 2021-03-23  14:30:00   2021/3/23 14:30:00           heat       heatOff
# 29673 2021-03-23  14:35:00   2021/3/23 14:35:00           heat       heatOff
# 29674 2021-03-23  14:40:00   2021/3/23 14:40:00           heat       heatOff
# 29675 2021-03-23  14:45:00   2021/3/23 14:45:00           heat       heatOff
#
#       Calendar Event Program Mode  Cool Set Temp (C)  Heat Set Temp (C)  \
# 0               auto         Home               21.0               21.0
# 1               auto         Home               21.0               21.0
# 2               auto         Home               21.0               21.0
# 3               auto         Home               21.0               21.0
# 4               auto         Home               21.0               21.0
# ...              ...          ...                ...                ...
# 29671            NaN         Home               21.0               21.0
# 29672            NaN         Home               21.0               21.0
# 29673            NaN         Home               21.0               21.0
# 29674            NaN         Home               21.0               21.0
# 29675            NaN         Home               21.0               21.0
#
#        Current Temp (C)  ...  Thermostat Motion  Bedroom (C)  Bedroom2  \
# 0                  21.3  ...                1.0         21.6       0.0
# 1                  21.1  ...                1.0         21.6       0.0
# 2                  20.9  ...                0.0         21.6       0.0
# 3                  20.7  ...                0.0         21.6       0.0
# 4                  20.6  ...                1.0         21.6       0.0
# ...                 ...  ...                ...          ...       ...
# 29671              21.2  ...                0.0         21.9       0.0
# 29672              21.1  ...                0.0         21.9       0.0
# 29673              21.1  ...                0.0         21.9       0.0
# 29674              21.1  ...                0.0         21.9       0.0
# 29675              21.1  ...                1.0         21.9       0.0
#
#        3rd floor landing (C)  3rd floor landing2  3rd floor room (C)  \
# 0                       20.9                 0.0                21.0
# 1                       20.9                 0.0                20.9
# 2                       20.8                 0.0                20.8
# 3                       20.8                 0.0                20.8
# 4                       20.8                 0.0                20.8
# ...                      ...                 ...                 ...
# 29671                   21.8                 0.0                21.3
# 29672                   21.8                 0.0                21.3
# 29673                   21.8                 1.0                21.3
# 29674                   21.8                 1.0                21.3
# 29675                   21.8                 0.0                21.3
#
#        3rd floor room2  Basement (C)  Basement2  Heat Stage 1 (min)
# 0                  0.0          22.8        0.0                0.00
# 1                  0.0          22.7        1.0                0.00
# 2                  0.0          22.7        1.0                0.00
# 3                  0.0          22.8        0.0                2.25
# 4                  0.0          22.8        0.0                5.00
# ...                ...           ...        ...                 ...
# 29671              0.0          22.0        1.0                0.00
# 29672              0.0          22.1        0.0                0.00
# 29673              0.0          22.1        0.0                0.00
# 29674              0.0          22.1        0.0                0.00
# 29675              0.0          22.1        1.0                0.00
#
# [29676 rows x 28 columns]

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    
    n_vars = data.shape[1]
    columns = data.columns
    df = pd.DataFrame(data)
    
    df_new = pd.DataFrame()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        for j in range(n_vars):
            df_new['var%d(t-%d)' % (j+1, i)] = df.shift(i)[columns[j]]
   
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        
        for j in range(n_vars):
            if i == 0:
                name = 'var%d(t)' % (j+1)
            else:
                name = 'var%d(t+%d)' % (j+1, i)
            df_new[name] = df.shift(-i)[columns[j]]
    
    if dropnan:
        df_new.dropna(inplace=True)
    return df_new

# %% [markdown]
# total data correlation

# %%
house_data.corr()
# Out:
#                             Cool Set Temp (C)  Heat Set Temp (C)  \
# Cool Set Temp (C)                         NaN                NaN
# Heat Set Temp (C)                         NaN                NaN
# Current Temp (C)                          NaN                NaN
# Current Humidity (%RH)                    NaN                NaN
# Outdoor Temp (C)                          NaN                NaN
# Wind Speed (km/h)                         NaN                NaN
# Cool Stage 1 (sec)                        NaN                NaN
# Heat Stage 1 (sec)                        NaN                NaN
# Fan (sec)                                 NaN                NaN
# Thermostat Temperature (C)                NaN                NaN
# Thermostat Humidity (%RH)                 NaN                NaN
# Thermostat Motion                         NaN                NaN
# Bedroom (C)                               NaN                NaN
# Bedroom2                                  NaN                NaN
# 3rd floor landing (C)                     NaN                NaN
# 3rd floor landing2                        NaN                NaN
# 3rd floor room (C)                        NaN                NaN
# 3rd floor room2                           NaN                NaN
# Basement (C)                              NaN                NaN
# Basement2                                 NaN                NaN
# Heat Stage 1 (min)                        NaN                NaN
#
#                             Current Temp (C)  Current Humidity (%RH)  \
# Cool Set Temp (C)                        NaN                     NaN
# Heat Set Temp (C)                        NaN                     NaN
# Current Temp (C)                    1.000000               -0.050936
# Current Humidity (%RH)             -0.050936                1.000000
# Outdoor Temp (C)                    0.224394                0.429445
# Wind Speed (km/h)                        NaN                     NaN
# Cool Stage 1 (sec)                       NaN                     NaN
# Heat Stage 1 (sec)                 -0.533121               -0.022963
# Fan (sec)                          -0.518796               -0.017967
# Thermostat Temperature (C)          1.000000               -0.050936
# Thermostat Humidity (%RH)          -0.050936                1.000000
# Thermostat Motion                   0.120854               -0.051489
# Bedroom (C)                         0.027534                0.492793
# Bedroom2                            0.012867               -0.020418
# 3rd floor landing (C)               0.327321                0.157072
# 3rd floor landing2                 -0.014947               -0.001381
# 3rd floor room (C)                  0.145654                0.455256
# 3rd floor room2                    -0.002999                0.007348
# Basement (C)                       -0.086888                0.764315
# Basement2                           0.028282               -0.002645
# Heat Stage 1 (min)                 -0.533121               -0.022963
#
#                             Outdoor Temp (C)  Wind Speed (km/h)  \
# Cool Set Temp (C)                        NaN                NaN
# Heat Set Temp (C)                        NaN                NaN
# Current Temp (C)                    0.224394                NaN
# Current Humidity (%RH)              0.429445                NaN
# Outdoor Temp (C)                    1.000000                NaN
# Wind Speed (km/h)                        NaN                NaN
# Cool Stage 1 (sec)                       NaN                NaN
# Heat Stage 1 (sec)                 -0.242169                NaN
# Fan (sec)                          -0.244116                NaN
# Thermostat Temperature (C)          0.224394                NaN
# Thermostat Humidity (%RH)           0.429445                NaN
# Thermostat Motion                   0.093172                NaN
# Bedroom (C)                         0.078521                NaN
# Bedroom2                            0.004894                NaN
# 3rd floor landing (C)               0.585512                NaN
# 3rd floor landing2                 -0.061094                NaN
# 3rd floor room (C)                  0.400828                NaN
# 3rd floor room2                    -0.000324                NaN
# Basement (C)                        0.157771                NaN
# Basement2                           0.048924                NaN
# Heat Stage 1 (min)                 -0.242169                NaN
#
#                             Cool Stage 1 (sec)  Heat Stage 1 (sec)  Fan (sec)  \
# Cool Set Temp (C)                          NaN                 NaN        NaN
# Heat Set Temp (C)                          NaN                 NaN        NaN
# Current Temp (C)                           NaN           -0.533121  -0.518796
# Current Humidity (%RH)                     NaN           -0.022963  -0.017967
# Outdoor Temp (C)                           NaN           -0.242169  -0.244116
# Wind Speed (km/h)                          NaN                 NaN        NaN
# Cool Stage 1 (sec)                         NaN                 NaN        NaN
# Heat Stage 1 (sec)                         NaN            1.000000   0.993693
# Fan (sec)                                  NaN            0.993693   1.000000
# Thermostat Temperature (C)                 NaN           -0.533121  -0.518796
# Thermostat Humidity (%RH)                  NaN           -0.022963  -0.017967
# Thermostat Motion                          NaN           -0.096387  -0.100757
# Bedroom (C)                                NaN           -0.054004  -0.053840
# Bedroom2                                   NaN           -0.028861  -0.029983
# 3rd floor landing (C)                      NaN           -0.360813  -0.368794
# 3rd floor landing2                         NaN            0.010429   0.011884
# 3rd floor room (C)                         NaN           -0.223769  -0.218105
# 3rd floor room2                            NaN           -0.011213  -0.012120
# Basement (C)                               NaN            0.059485   0.062258
# Basement2                                  NaN           -0.011577  -0.013597
# Heat Stage 1 (min)                         NaN            1.000000   0.993693
#
#                             Thermostat Temperature (C)  ...  \
# Cool Set Temp (C)                                  NaN  ...
# Heat Set Temp (C)                                  NaN  ...
# Current Temp (C)                              1.000000  ...
# Current Humidity (%RH)                       -0.050936  ...
# Outdoor Temp (C)                              0.224394  ...
# Wind Speed (km/h)                                  NaN  ...
# Cool Stage 1 (sec)                                 NaN  ...
# Heat Stage 1 (sec)                           -0.533121  ...
# Fan (sec)                                    -0.518796  ...
# Thermostat Temperature (C)                    1.000000  ...
# Thermostat Humidity (%RH)                    -0.050936  ...
# Thermostat Motion                             0.120854  ...
# Bedroom (C)                                   0.027534  ...
# Bedroom2                                      0.012867  ...
# 3rd floor landing (C)                         0.327321  ...
# 3rd floor landing2                           -0.014947  ...
# 3rd floor room (C)                            0.145654  ...
# 3rd floor room2                              -0.002999  ...
# Basement (C)                                 -0.086888  ...
# Basement2                                     0.028282  ...
# Heat Stage 1 (min)                           -0.533121  ...
#
#                             Thermostat Motion  Bedroom (C)  Bedroom2  \
# Cool Set Temp (C)                         NaN          NaN       NaN
# Heat Set Temp (C)                         NaN          NaN       NaN
# Current Temp (C)                     0.120854     0.027534  0.012867
# Current Humidity (%RH)              -0.051489     0.492793 -0.020418
# Outdoor Temp (C)                     0.093172     0.078521  0.004894
# Wind Speed (km/h)                         NaN          NaN       NaN
# Cool Stage 1 (sec)                        NaN          NaN       NaN
# Heat Stage 1 (sec)                  -0.096387    -0.054004 -0.028861
# Fan (sec)                           -0.100757    -0.053840 -0.029983
# Thermostat Temperature (C)           0.120854     0.027534  0.012867
# Thermostat Humidity (%RH)           -0.051489     0.492793 -0.020418
# Thermostat Motion                    1.000000    -0.015652  0.079530
# Bedroom (C)                         -0.015652     1.000000 -0.023569
# Bedroom2                             0.079530    -0.023569  1.000000
# 3rd floor landing (C)                0.150509     0.239141  0.043566
# 3rd floor landing2                   0.000128     0.162436 -0.012170
# 3rd floor room (C)                  -0.098885     0.722003 -0.055306
# 3rd floor room2                      0.037909    -0.002536  0.089314
# Basement (C)                        -0.163888     0.735574 -0.055352
# Basement2                            0.273427     0.043881  0.037418
# Heat Stage 1 (min)                  -0.096387    -0.054004 -0.028861
#
#                             3rd floor landing (C)  3rd floor landing2  \
# Cool Set Temp (C)                             NaN                 NaN
# Heat Set Temp (C)                             NaN                 NaN
# Current Temp (C)                         0.327321           -0.014947
# Current Humidity (%RH)                   0.157072           -0.001381
# Outdoor Temp (C)                         0.585512           -0.061094
# Wind Speed (km/h)                             NaN                 NaN
# Cool Stage 1 (sec)                            NaN                 NaN
# Heat Stage 1 (sec)                      -0.360813            0.010429
# Fan (sec)                               -0.368794            0.011884
# Thermostat Temperature (C)               0.327321           -0.014947
# Thermostat Humidity (%RH)                0.157072           -0.001381
# Thermostat Motion                        0.150509            0.000128
# Bedroom (C)                              0.239141            0.162436
# Bedroom2                                 0.043566           -0.012170
# 3rd floor landing (C)                    1.000000            0.065785
# 3rd floor landing2                       0.065785            1.000000
# 3rd floor room (C)                       0.510821            0.134556
# 3rd floor room2                          0.015978           -0.006396
# Basement (C)                            -0.031534            0.031077
# Basement2                                0.101626           -0.008965
# Heat Stage 1 (min)                      -0.360813            0.010429
#
#                             3rd floor room (C)  3rd floor room2  Basement (C)  \
# Cool Set Temp (C)                          NaN              NaN           NaN
# Heat Set Temp (C)                          NaN              NaN           NaN
# Current Temp (C)                      0.145654        -0.002999     -0.086888
# Current Humidity (%RH)                0.455256         0.007348      0.764315
# Outdoor Temp (C)                      0.400828        -0.000324      0.157771
# Wind Speed (km/h)                          NaN              NaN           NaN
# Cool Stage 1 (sec)                         NaN              NaN           NaN
# Heat Stage 1 (sec)                   -0.223769        -0.011213      0.059485
# Fan (sec)                            -0.218105        -0.012120      0.062258
# Thermostat Temperature (C)            0.145654        -0.002999     -0.086888
# Thermostat Humidity (%RH)             0.455256         0.007348      0.764315
# Thermostat Motion                    -0.098885         0.037909     -0.163888
# Bedroom (C)                           0.722003        -0.002536      0.735574
# Bedroom2                             -0.055306         0.089314     -0.055352
# 3rd floor landing (C)                 0.510821         0.015978     -0.031534
# 3rd floor landing2                    0.134556        -0.006396      0.031077
# 3rd floor room (C)                    1.000000        -0.006909      0.582691
# 3rd floor room2                      -0.006909         1.000000     -0.014428
# Basement (C)                          0.582691        -0.014428      1.000000
# Basement2                             0.017129         0.044313     -0.042165
# Heat Stage 1 (min)                   -0.223769        -0.011213      0.059485
#
#                             Basement2  Heat Stage 1 (min)
# Cool Set Temp (C)                 NaN                 NaN
# Heat Set Temp (C)                 NaN                 NaN
# Current Temp (C)             0.028282           -0.533121
# Current Humidity (%RH)      -0.002645           -0.022963
# Outdoor Temp (C)             0.048924           -0.242169
# Wind Speed (km/h)                 NaN                 NaN
# Cool Stage 1 (sec)                NaN                 NaN
# Heat Stage 1 (sec)          -0.011577            1.000000
# Fan (sec)                   -0.013597            0.993693
# Thermostat Temperature (C)   0.028282           -0.533121
# Thermostat Humidity (%RH)   -0.002645           -0.022963
# Thermostat Motion            0.273427           -0.096387
# Bedroom (C)                  0.043881           -0.054004
# Bedroom2                     0.037418           -0.028861
# 3rd floor landing (C)        0.101626           -0.360813
# 3rd floor landing2          -0.008965            0.010429
# 3rd floor room (C)           0.017129           -0.223769
# 3rd floor room2              0.044313           -0.011213
# Basement (C)                -0.042165            0.059485
# Basement2                    1.000000           -0.011577
# Heat Stage 1 (min)          -0.011577            1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(house_data.corr())
plt.show()

# %% [markdown]
# day-time correlation

# %%
import datetime
house_data["Time"]=pd.to_datetime(house_data["Time"], format='%H:%M:%S')

# %%
day_time_data = house_data[house_data['Time'].dt.hour.isin(np.arange(6, 18))]

# %%
day_time_data.corr()
# Out:
#                             Cool Set Temp (C)  Heat Set Temp (C)  \
# Cool Set Temp (C)                         NaN                NaN
# Heat Set Temp (C)                         NaN                NaN
# Current Temp (C)                          NaN                NaN
# Current Humidity (%RH)                    NaN                NaN
# Outdoor Temp (C)                          NaN                NaN
# Wind Speed (km/h)                         NaN                NaN
# Cool Stage 1 (sec)                        NaN                NaN
# Heat Stage 1 (sec)                        NaN                NaN
# Fan (sec)                                 NaN                NaN
# Thermostat Temperature (C)                NaN                NaN
# Thermostat Humidity (%RH)                 NaN                NaN
# Thermostat Motion                         NaN                NaN
# Bedroom (C)                               NaN                NaN
# Bedroom2                                  NaN                NaN
# 3rd floor landing (C)                     NaN                NaN
# 3rd floor landing2                        NaN                NaN
# 3rd floor room (C)                        NaN                NaN
# 3rd floor room2                           NaN                NaN
# Basement (C)                              NaN                NaN
# Basement2                                 NaN                NaN
# Heat Stage 1 (min)                        NaN                NaN
#
#                             Current Temp (C)  Current Humidity (%RH)  \
# Cool Set Temp (C)                        NaN                     NaN
# Heat Set Temp (C)                        NaN                     NaN
# Current Temp (C)                    1.000000               -0.114442
# Current Humidity (%RH)             -0.114442                1.000000
# Outdoor Temp (C)                    0.215257                0.377899
# Wind Speed (km/h)                        NaN                     NaN
# Cool Stage 1 (sec)                       NaN                     NaN
# Heat Stage 1 (sec)                 -0.474130                0.037469
# Fan (sec)                          -0.465315                0.043964
# Thermostat Temperature (C)          1.000000               -0.114442
# Thermostat Humidity (%RH)          -0.114442                1.000000
# Thermostat Motion                   0.090015               -0.077153
# Bedroom (C)                        -0.010257                0.451741
# Bedroom2                            0.005765               -0.028130
# 3rd floor landing (C)               0.308614                0.080329
# 3rd floor landing2                 -0.024089                0.014174
# 3rd floor room (C)                  0.069652                0.476071
# 3rd floor room2                    -0.010284                0.010656
# Basement (C)                       -0.094499                0.738263
# Basement2                           0.013871               -0.012214
# Heat Stage 1 (min)                 -0.474130                0.037469
#
#                             Outdoor Temp (C)  Wind Speed (km/h)  \
# Cool Set Temp (C)                        NaN                NaN
# Heat Set Temp (C)                        NaN                NaN
# Current Temp (C)                    0.215257                NaN
# Current Humidity (%RH)              0.377899                NaN
# Outdoor Temp (C)                    1.000000                NaN
# Wind Speed (km/h)                        NaN                NaN
# Cool Stage 1 (sec)                       NaN                NaN
# Heat Stage 1 (sec)                 -0.231077                NaN
# Fan (sec)                          -0.233480                NaN
# Thermostat Temperature (C)          0.215257                NaN
# Thermostat Humidity (%RH)           0.377899                NaN
# Thermostat Motion                   0.073954                NaN
# Bedroom (C)                         0.110259                NaN
# Bedroom2                           -0.001855                NaN
# 3rd floor landing (C)               0.554245                NaN
# 3rd floor landing2                 -0.054755                NaN
# 3rd floor room (C)                  0.385747                NaN
# 3rd floor room2                    -0.007231                NaN
# Basement (C)                        0.142917                NaN
# Basement2                           0.047155                NaN
# Heat Stage 1 (min)                 -0.231077                NaN
#
#                             Cool Stage 1 (sec)  Heat Stage 1 (sec)  Fan (sec)  \
# Cool Set Temp (C)                          NaN                 NaN        NaN
# Heat Set Temp (C)                          NaN                 NaN        NaN
# Current Temp (C)                           NaN           -0.474130  -0.465315
# Current Humidity (%RH)                     NaN            0.037469   0.043964
# Outdoor Temp (C)                           NaN           -0.231077  -0.233480
# Wind Speed (km/h)                          NaN                 NaN        NaN
# Cool Stage 1 (sec)                         NaN                 NaN        NaN
# Heat Stage 1 (sec)                         NaN            1.000000   0.993961
# Fan (sec)                                  NaN            0.993961   1.000000
# Thermostat Temperature (C)                 NaN           -0.474130  -0.465315
# Thermostat Humidity (%RH)                  NaN            0.037469   0.043964
# Thermostat Motion                          NaN           -0.082259  -0.086912
# Bedroom (C)                                NaN            0.010052   0.011889
# Bedroom2                                   NaN           -0.032043  -0.033248
# 3rd floor landing (C)                      NaN           -0.345981  -0.354406
# 3rd floor landing2                         NaN            0.007509   0.009482
# 3rd floor room (C)                         NaN           -0.114943  -0.109559
# 3rd floor room2                            NaN           -0.008234  -0.009304
# Basement (C)                               NaN            0.117392   0.121692
# Basement2                                  NaN            0.001899  -0.000611
# Heat Stage 1 (min)                         NaN            1.000000   0.993961
#
#                             Thermostat Temperature (C)  ...  \
# Cool Set Temp (C)                                  NaN  ...
# Heat Set Temp (C)                                  NaN  ...
# Current Temp (C)                              1.000000  ...
# Current Humidity (%RH)                       -0.114442  ...
# Outdoor Temp (C)                              0.215257  ...
# Wind Speed (km/h)                                  NaN  ...
# Cool Stage 1 (sec)                                 NaN  ...
# Heat Stage 1 (sec)                           -0.474130  ...
# Fan (sec)                                    -0.465315  ...
# Thermostat Temperature (C)                    1.000000  ...
# Thermostat Humidity (%RH)                    -0.114442  ...
# Thermostat Motion                             0.090015  ...
# Bedroom (C)                                  -0.010257  ...
# Bedroom2                                      0.005765  ...
# 3rd floor landing (C)                         0.308614  ...
# 3rd floor landing2                           -0.024089  ...
# 3rd floor room (C)                            0.069652  ...
# 3rd floor room2                              -0.010284  ...
# Basement (C)                                 -0.094499  ...
# Basement2                                     0.013871  ...
# Heat Stage 1 (min)                           -0.474130  ...
#
#                             Thermostat Motion  Bedroom (C)  Bedroom2  \
# Cool Set Temp (C)                         NaN          NaN       NaN
# Heat Set Temp (C)                         NaN          NaN       NaN
# Current Temp (C)                     0.090015    -0.010257  0.005765
# Current Humidity (%RH)              -0.077153     0.451741 -0.028130
# Outdoor Temp (C)                     0.073954     0.110259 -0.001855
# Wind Speed (km/h)                         NaN          NaN       NaN
# Cool Stage 1 (sec)                        NaN          NaN       NaN
# Heat Stage 1 (sec)                  -0.082259     0.010052 -0.032043
# Fan (sec)                           -0.086912     0.011889 -0.033248
# Thermostat Temperature (C)           0.090015    -0.010257  0.005765
# Thermostat Humidity (%RH)           -0.077153     0.451741 -0.028130
# Thermostat Motion                    1.000000    -0.058695  0.068047
# Bedroom (C)                         -0.058695     1.000000 -0.038103
# Bedroom2                             0.068047    -0.038103  1.000000
# 3rd floor landing (C)                0.115766     0.216628  0.043089
# 3rd floor landing2                  -0.003342     0.127312 -0.017529
# 3rd floor room (C)                  -0.090580     0.816575 -0.063564
# 3rd floor room2                      0.026963    -0.008622  0.087300
# Basement (C)                        -0.156607     0.745003 -0.060449
# Basement2                            0.246920     0.041990  0.032439
# Heat Stage 1 (min)                  -0.082259     0.010052 -0.032043
#
#                             3rd floor landing (C)  3rd floor landing2  \
# Cool Set Temp (C)                             NaN                 NaN
# Heat Set Temp (C)                             NaN                 NaN
# Current Temp (C)                         0.308614           -0.024089
# Current Humidity (%RH)                   0.080329            0.014174
# Outdoor Temp (C)                         0.554245           -0.054755
# Wind Speed (km/h)                             NaN                 NaN
# Cool Stage 1 (sec)                            NaN                 NaN
# Heat Stage 1 (sec)                      -0.345981            0.007509
# Fan (sec)                               -0.354406            0.009482
# Thermostat Temperature (C)               0.308614           -0.024089
# Thermostat Humidity (%RH)                0.080329            0.014174
# Thermostat Motion                        0.115766           -0.003342
# Bedroom (C)                              0.216628            0.127312
# Bedroom2                                 0.043089           -0.017529
# 3rd floor landing (C)                    1.000000            0.046075
# 3rd floor landing2                       0.046075            1.000000
# 3rd floor room (C)                       0.418557            0.119286
# 3rd floor room2                          0.010218           -0.009296
# Basement (C)                            -0.102049            0.023062
# Basement2                                0.099367           -0.014508
# Heat Stage 1 (min)                      -0.345981            0.007509
#
#                             3rd floor room (C)  3rd floor room2  Basement (C)  \
# Cool Set Temp (C)                          NaN              NaN           NaN
# Heat Set Temp (C)                          NaN              NaN           NaN
# Current Temp (C)                      0.069652        -0.010284     -0.094499
# Current Humidity (%RH)                0.476071         0.010656      0.738263
# Outdoor Temp (C)                      0.385747        -0.007231      0.142917
# Wind Speed (km/h)                          NaN              NaN           NaN
# Cool Stage 1 (sec)                         NaN              NaN           NaN
# Heat Stage 1 (sec)                   -0.114943        -0.008234      0.117392
# Fan (sec)                            -0.109559        -0.009304      0.121692
# Thermostat Temperature (C)            0.069652        -0.010284     -0.094499
# Thermostat Humidity (%RH)             0.476071         0.010656      0.738263
# Thermostat Motion                    -0.090580         0.026963     -0.156607
# Bedroom (C)                           0.816575        -0.008622      0.745003
# Bedroom2                             -0.063564         0.087300     -0.060449
# 3rd floor landing (C)                 0.418557         0.010218     -0.102049
# 3rd floor landing2                    0.119286        -0.009296      0.023062
# 3rd floor room (C)                    1.000000        -0.002803      0.642525
# 3rd floor room2                      -0.002803         1.000000     -0.010746
# Basement (C)                          0.642525        -0.010746      1.000000
# Basement2                             0.038867         0.040917     -0.037160
# Heat Stage 1 (min)                   -0.114943        -0.008234      0.117392
#
#                             Basement2  Heat Stage 1 (min)
# Cool Set Temp (C)                 NaN                 NaN
# Heat Set Temp (C)                 NaN                 NaN
# Current Temp (C)             0.013871           -0.474130
# Current Humidity (%RH)      -0.012214            0.037469
# Outdoor Temp (C)             0.047155           -0.231077
# Wind Speed (km/h)                 NaN                 NaN
# Cool Stage 1 (sec)                NaN                 NaN
# Heat Stage 1 (sec)           0.001899            1.000000
# Fan (sec)                   -0.000611            0.993961
# Thermostat Temperature (C)   0.013871           -0.474130
# Thermostat Humidity (%RH)   -0.012214            0.037469
# Thermostat Motion            0.246920           -0.082259
# Bedroom (C)                  0.041990            0.010052
# Bedroom2                     0.032439           -0.032043
# 3rd floor landing (C)        0.099367           -0.345981
# 3rd floor landing2          -0.014508            0.007509
# 3rd floor room (C)           0.038867           -0.114943
# 3rd floor room2              0.040917           -0.008234
# Basement (C)                -0.037160            0.117392
# Basement2                    1.000000            0.001899
# Heat Stage 1 (min)           0.001899            1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(day_time_data.corr())
plt.show()

# %%
night_data = house_data[house_data['Time'].dt.hour.isin([i for i in range(0, 7)]+[i for i in range(18,24)])]

# %%
night_data.corr()
# Out:
#                             Cool Set Temp (C)  Heat Set Temp (C)  \
# Cool Set Temp (C)                         NaN                NaN
# Heat Set Temp (C)                         NaN                NaN
# Current Temp (C)                          NaN                NaN
# Current Humidity (%RH)                    NaN                NaN
# Outdoor Temp (C)                          NaN                NaN
# Wind Speed (km/h)                         NaN                NaN
# Cool Stage 1 (sec)                        NaN                NaN
# Heat Stage 1 (sec)                        NaN                NaN
# Fan (sec)                                 NaN                NaN
# Thermostat Temperature (C)                NaN                NaN
# Thermostat Humidity (%RH)                 NaN                NaN
# Thermostat Motion                         NaN                NaN
# Bedroom (C)                               NaN                NaN
# Bedroom2                                  NaN                NaN
# 3rd floor landing (C)                     NaN                NaN
# 3rd floor landing2                        NaN                NaN
# 3rd floor room (C)                        NaN                NaN
# 3rd floor room2                           NaN                NaN
# Basement (C)                              NaN                NaN
# Basement2                                 NaN                NaN
# Heat Stage 1 (min)                        NaN                NaN
#
#                             Current Temp (C)  Current Humidity (%RH)  \
# Cool Set Temp (C)                        NaN                     NaN
# Heat Set Temp (C)                        NaN                     NaN
# Current Temp (C)                    1.000000                0.077502
# Current Humidity (%RH)              0.077502                1.000000
# Outdoor Temp (C)                    0.229002                0.503298
# Wind Speed (km/h)                        NaN                     NaN
# Cool Stage 1 (sec)                       NaN                     NaN
# Heat Stage 1 (sec)                 -0.726140               -0.086562
# Fan (sec)                          -0.694811               -0.083514
# Thermostat Temperature (C)          1.000000                0.077502
# Thermostat Humidity (%RH)           0.077502                1.000000
# Thermostat Motion                   0.017401                0.013693
# Bedroom (C)                         0.074891                0.546244
# Bedroom2                                 NaN                     NaN
# 3rd floor landing (C)               0.330375                0.284436
# 3rd floor landing2                  0.001604               -0.018011
# 3rd floor room (C)                  0.426509                0.443224
# 3rd floor room2                          NaN                     NaN
# Basement (C)                        0.004248                0.830166
# Basement2                          -0.006519                0.037840
# Heat Stage 1 (min)                 -0.726140               -0.086562
#
#                             Outdoor Temp (C)  Wind Speed (km/h)  \
# Cool Set Temp (C)                        NaN                NaN
# Heat Set Temp (C)                        NaN                NaN
# Current Temp (C)                    0.229002                NaN
# Current Humidity (%RH)              0.503298                NaN
# Outdoor Temp (C)                    1.000000                NaN
# Wind Speed (km/h)                        NaN                NaN
# Cool Stage 1 (sec)                       NaN                NaN
# Heat Stage 1 (sec)                 -0.230836                NaN
# Fan (sec)                          -0.231184                NaN
# Thermostat Temperature (C)          0.229002                NaN
# Thermostat Humidity (%RH)           0.503298                NaN
# Thermostat Motion                   0.052300                NaN
# Bedroom (C)                         0.023517                NaN
# Bedroom2                                 NaN                NaN
# 3rd floor landing (C)               0.620846                NaN
# 3rd floor landing2                 -0.062942                NaN
# 3rd floor room (C)                  0.473122                NaN
# 3rd floor room2                          NaN                NaN
# Basement (C)                        0.234650                NaN
# Basement2                           0.012933                NaN
# Heat Stage 1 (min)                 -0.230836                NaN
#
#                             Cool Stage 1 (sec)  Heat Stage 1 (sec)  Fan (sec)  \
# Cool Set Temp (C)                          NaN                 NaN        NaN
# Heat Set Temp (C)                          NaN                 NaN        NaN
# Current Temp (C)                           NaN           -0.726140  -0.694811
# Current Humidity (%RH)                     NaN           -0.086562  -0.083514
# Outdoor Temp (C)                           NaN           -0.230836  -0.231184
# Wind Speed (km/h)                          NaN                 NaN        NaN
# Cool Stage 1 (sec)                         NaN                 NaN        NaN
# Heat Stage 1 (sec)                         NaN            1.000000   0.993269
# Fan (sec)                                  NaN            0.993269   1.000000
# Thermostat Temperature (C)                 NaN           -0.726140  -0.694811
# Thermostat Humidity (%RH)                  NaN           -0.086562  -0.083514
# Thermostat Motion                          NaN           -0.022619  -0.023160
# Bedroom (C)                                NaN           -0.101582  -0.103046
# Bedroom2                                   NaN                 NaN        NaN
# 3rd floor landing (C)                      NaN           -0.354518  -0.360607
# 3rd floor landing2                         NaN            0.012817   0.014094
# 3rd floor room (C)                         NaN           -0.402278  -0.398146
# 3rd floor room2                            NaN                 NaN        NaN
# Basement (C)                               NaN           -0.055422  -0.056659
# Basement2                                  NaN            0.015755   0.016075
# Heat Stage 1 (min)                         NaN            1.000000   0.993269
#
#                             Thermostat Temperature (C)  ...  \
# Cool Set Temp (C)                                  NaN  ...
# Heat Set Temp (C)                                  NaN  ...
# Current Temp (C)                              1.000000  ...
# Current Humidity (%RH)                        0.077502  ...
# Outdoor Temp (C)                              0.229002  ...
# Wind Speed (km/h)                                  NaN  ...
# Cool Stage 1 (sec)                                 NaN  ...
# Heat Stage 1 (sec)                           -0.726140  ...
# Fan (sec)                                    -0.694811  ...
# Thermostat Temperature (C)                    1.000000  ...
# Thermostat Humidity (%RH)                     0.077502  ...
# Thermostat Motion                             0.017401  ...
# Bedroom (C)                                   0.074891  ...
# Bedroom2                                           NaN  ...
# 3rd floor landing (C)                         0.330375  ...
# 3rd floor landing2                            0.001604  ...
# 3rd floor room (C)                            0.426509  ...
# 3rd floor room2                                    NaN  ...
# Basement (C)                                  0.004248  ...
# Basement2                                    -0.006519  ...
# Heat Stage 1 (min)                           -0.726140  ...
#
#                             Thermostat Motion  Bedroom (C)  Bedroom2  \
# Cool Set Temp (C)                         NaN          NaN       NaN
# Heat Set Temp (C)                         NaN          NaN       NaN
# Current Temp (C)                     0.017401     0.074891       NaN
# Current Humidity (%RH)               0.013693     0.546244       NaN
# Outdoor Temp (C)                     0.052300     0.023517       NaN
# Wind Speed (km/h)                         NaN          NaN       NaN
# Cool Stage 1 (sec)                        NaN          NaN       NaN
# Heat Stage 1 (sec)                  -0.022619    -0.101582       NaN
# Fan (sec)                           -0.023160    -0.103046       NaN
# Thermostat Temperature (C)           0.017401     0.074891       NaN
# Thermostat Humidity (%RH)            0.013693     0.546244       NaN
# Thermostat Motion                    1.000000    -0.026368       NaN
# Bedroom (C)                         -0.026368     1.000000       NaN
# Bedroom2                                  NaN          NaN       NaN
# 3rd floor landing (C)                0.068565     0.252506       NaN
# 3rd floor landing2                   0.006666     0.204796       NaN
# 3rd floor room (C)                   0.011102     0.634541       NaN
# 3rd floor room2                           NaN          NaN       NaN
# Basement (C)                        -0.042766     0.789934       NaN
# Basement2                            0.343473     0.015465       NaN
# Heat Stage 1 (min)                  -0.022619    -0.101582       NaN
#
#                             3rd floor landing (C)  3rd floor landing2  \
# Cool Set Temp (C)                             NaN                 NaN
# Heat Set Temp (C)                             NaN                 NaN
# Current Temp (C)                         0.330375            0.001604
# Current Humidity (%RH)                   0.284436           -0.018011
# Outdoor Temp (C)                         0.620846           -0.062942
# Wind Speed (km/h)                             NaN                 NaN
# Cool Stage 1 (sec)                            NaN                 NaN
# Heat Stage 1 (sec)                      -0.354518            0.012817
# Fan (sec)                               -0.360607            0.014094
# Thermostat Temperature (C)               0.330375            0.001604
# Thermostat Humidity (%RH)                0.284436           -0.018011
# Thermostat Motion                        0.068565            0.006666
# Bedroom (C)                              0.252506            0.204796
# Bedroom2                                      NaN                 NaN
# 3rd floor landing (C)                    1.000000            0.098134
# 3rd floor landing2                       0.098134            1.000000
# 3rd floor room (C)                       0.758082            0.162418
# 3rd floor room2                               NaN                 NaN
# Basement (C)                             0.177917            0.046023
# Basement2                                0.033807            0.002316
# Heat Stage 1 (min)                      -0.354518            0.012817
#
#                             3rd floor room (C)  3rd floor room2  Basement (C)  \
# Cool Set Temp (C)                          NaN              NaN           NaN
# Heat Set Temp (C)                          NaN              NaN           NaN
# Current Temp (C)                      0.426509              NaN      0.004248
# Current Humidity (%RH)                0.443224              NaN      0.830166
# Outdoor Temp (C)                      0.473122              NaN      0.234650
# Wind Speed (km/h)                          NaN              NaN           NaN
# Cool Stage 1 (sec)                         NaN              NaN           NaN
# Heat Stage 1 (sec)                   -0.402278              NaN     -0.055422
# Fan (sec)                            -0.398146              NaN     -0.056659
# Thermostat Temperature (C)            0.426509              NaN      0.004248
# Thermostat Humidity (%RH)             0.443224              NaN      0.830166
# Thermostat Motion                     0.011102              NaN     -0.042766
# Bedroom (C)                           0.634541              NaN      0.789934
# Bedroom2                                   NaN              NaN           NaN
# 3rd floor landing (C)                 0.758082              NaN      0.177917
# 3rd floor landing2                    0.162418              NaN      0.046023
# 3rd floor room (C)                    1.000000              NaN      0.470305
# 3rd floor room2                            NaN              NaN           NaN
# Basement (C)                          0.470305              NaN      1.000000
# Basement2                             0.008208              NaN      0.018376
# Heat Stage 1 (min)                   -0.402278              NaN     -0.055422
#
#                             Basement2  Heat Stage 1 (min)
# Cool Set Temp (C)                 NaN                 NaN
# Heat Set Temp (C)                 NaN                 NaN
# Current Temp (C)            -0.006519           -0.726140
# Current Humidity (%RH)       0.037840           -0.086562
# Outdoor Temp (C)             0.012933           -0.230836
# Wind Speed (km/h)                 NaN                 NaN
# Cool Stage 1 (sec)                NaN                 NaN
# Heat Stage 1 (sec)           0.015755            1.000000
# Fan (sec)                    0.016075            0.993269
# Thermostat Temperature (C)  -0.006519           -0.726140
# Thermostat Humidity (%RH)    0.037840           -0.086562
# Thermostat Motion            0.343473           -0.022619
# Bedroom (C)                  0.015465           -0.101582
# Bedroom2                          NaN                 NaN
# 3rd floor landing (C)        0.033807           -0.354518
# 3rd floor landing2           0.002316            0.012817
# 3rd floor room (C)           0.008208           -0.402278
# 3rd floor room2                   NaN                 NaN
# Basement (C)                 0.018376           -0.055422
# Basement2                    1.000000            0.015755
# Heat Stage 1 (min)           0.015755            1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(night_data.corr())
plt.show()

# %%
house_data[["Heat Stage 1 (sec)","Outdoor Temp (C)"]].corr()
# Out:
#                     Heat Stage 1 (sec)  Outdoor Temp (C)
# Heat Stage 1 (sec)            1.000000         -0.242169
# Outdoor Temp (C)             -0.242169          1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(house_data[["Heat Stage 1 (sec)","Outdoor Temp (C)"]].corr())
plt.show()

# %%
day_time_data[["Heat Stage 1 (sec)","Outdoor Temp (C)"]].corr()
# Out:
#                     Heat Stage 1 (sec)  Outdoor Temp (C)
# Heat Stage 1 (sec)            1.000000         -0.231077
# Outdoor Temp (C)             -0.231077          1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(day_time_data[["Heat Stage 1 (sec)","Outdoor Temp (C)"]].corr())
plt.show()

# %%
night_data[["Heat Stage 1 (sec)","Outdoor Temp (C)"]].corr()
# Out:
#                     Heat Stage 1 (sec)  Outdoor Temp (C)
# Heat Stage 1 (sec)            1.000000         -0.230836
# Outdoor Temp (C)             -0.230836          1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(night_data[["Heat Stage 1 (sec)","Outdoor Temp (C)"]].corr())
plt.show()

# %%
daily_activity_member = house_data.groupby(by = [ 'Outdoor Temp (C)','Heat Stage 1 (min)']).count()['Heat Stage 1 (sec)'].unstack()

plt.figure(figsize = (20, 10))

sns.heatmap(daily_activity_member, cmap = 'Oranges')

plt.title('Outside Temperaturxe vs Heat Stage1 (min)', fontsize = 14)
plt.xlabel('Heat Stage1 (min)', fontsize = 14)
plt.ylabel('Outside Temperature', fontsize = 14)
plt.show()

# %%
reframed_totle = series_to_supervised(house_data[["Outdoor Temp (C)","Heat Stage 1 (min)"]], 12, 1)
reframed_totle
# Out:
#        var1(t-12)  var2(t-12)  var1(t-11)  var2(t-11)  var1(t-10)  var2(t-10)  \
# 12            5.0        0.00         5.0        0.00         5.2        0.00
# 13            5.0        0.00         5.2        0.00         5.2        2.25
# 14            5.2        0.00         5.2        2.25         5.2        5.00
# 15            5.2        2.25         5.2        5.00         5.2        5.00
# 16            5.2        5.00         5.2        5.00         5.2        5.00
# ...           ...         ...         ...         ...         ...         ...
# 29671        14.4        0.00        14.9        0.00        14.9        0.00
# 29672        14.9        0.00        14.9        0.00        14.9        0.00
# 29673        14.9        0.00        14.9        0.00        14.9        0.00
# 29674        14.9        0.00        14.9        0.00        14.9        0.00
# 29675        14.9        0.00        14.9        0.00        14.9        0.00
#
#        var1(t-9)  var2(t-9)  var1(t-8)  var2(t-8)  ...  var1(t-4)  var2(t-4)  \
# 12           5.2       2.25        5.2       5.00  ...        5.4        0.0
# 13           5.2       5.00        5.2       5.00  ...        5.4        0.0
# 14           5.2       5.00        5.2       5.00  ...        5.4        0.0
# 15           5.2       5.00        5.2       0.75  ...        5.4        0.0
# 16           5.2       0.75        5.4       0.00  ...        5.4        0.0
# ...          ...        ...        ...        ...  ...        ...        ...
# 29671       14.9       0.00       14.9       0.00  ...       15.2        0.0
# 29672       14.9       0.00       14.9       0.00  ...       15.2        0.0
# 29673       14.9       0.00       14.9       0.00  ...       15.2        0.0
# 29674       14.9       0.00       15.2       0.00  ...       15.2        0.0
# 29675       15.2       0.00       15.2       0.00  ...       15.2        0.0
#
#        var1(t-3)  var2(t-3)  var1(t-2)  var2(t-2)  var1(t-1)  var2(t-1)  \
# 12           5.4        0.0        5.4       0.00        5.4       0.00
# 13           5.4        0.0        5.4       0.00        5.4       0.00
# 14           5.4        0.0        5.4       0.00        5.4       0.00
# 15           5.4        0.0        5.4       0.00        5.3       4.25
# 16           5.4        0.0        5.3       4.25        5.3       5.00
# ...          ...        ...        ...        ...        ...        ...
# 29671       15.2        0.0       15.2       0.00       15.2       0.00
# 29672       15.2        0.0       15.2       0.00       15.2       0.00
# 29673       15.2        0.0       15.2       0.00       15.7       0.00
# 29674       15.2        0.0       15.7       0.00       15.7       0.00
# 29675       15.7        0.0       15.7       0.00       15.7       0.00
#
#        var1(t)  var2(t)
# 12         5.4     0.00
# 13         5.4     0.00
# 14         5.3     4.25
# 15         5.3     5.00
# 16         5.3     1.50
# ...        ...      ...
# 29671     15.2     0.00
# 29672     15.7     0.00
# 29673     15.7     0.00
# 29674     15.7     0.00
# 29675     15.7     0.00
#
# [29383 rows x 26 columns]

# %%
y_auxHeat = reframed_totle['var2(t)']
#y_auxHeat = to_categorical(y_auxHeat)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(np.array(y_auxHeat).reshape(-1,1))
y_auxHeat = sc.transform(np.array(y_auxHeat).reshape(-1,1))

# %%
y_auxHeat.shape
# Out:
# (29383, 1)

# %%
X = reframed_totle.drop(labels = ['var2(t)'], axis = 1)
sc = StandardScaler()
sc.fit(X)
X = sc.transform(X)
#X_train = X.iloc[:23584,]
X_train = X[:23584,]
y_train = y_auxHeat[:23584,]
#X_test = X.iloc[23584:]
X_test = X[23584:]
y_test = y_auxHeat[23584:]
#X_train = X_train.values
#X_test = X_test.values

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model    
model = linear_model.LinearRegression()

model.fit(X,y_auxHeat)
predict_y = model.predict(X)

r2_score(predict_y,y_auxHeat)
# Out:
# 0.5535604370260105

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((23584, 25), (23584, 1), (5799, 25), (5799, 1))

# %%
y_test.shape
# Out:
# (5799, 1)

# %%
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu', input_dim = 25))

# Adding the second hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'normal', activation = 'linear'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'mean_absolute_error', metrics = ['mse']) 

# Fitting the ANN to the Training set
history = classifier.fit(X_train, y_train, validation_data = (X_test, y_test), batch_size = 64, epochs = 50, shuffle = True)
# Out:
# Epoch 1/50
# 369/369 [==============================] - 0s 850us/step - loss: 0.4436 - mse: 0.4109 - val_loss: 0.2667 - val_mse: 0.2391
# Epoch 2/50
# 369/369 [==============================] - 0s 718us/step - loss: 0.2665 - mse: 0.2256 - val_loss: 0.2389 - val_mse: 0.2265
# Epoch 3/50
# 369/369 [==============================] - 0s 633us/step - loss: 0.2370 - mse: 0.2075 - val_loss: 0.2087 - val_mse: 0.2039
# Epoch 4/50
# 369/369 [==============================] - 0s 722us/step - loss: 0.2230 - mse: 0.1986 - val_loss: 0.1963 - val_mse: 0.2013
# Epoch 5/50
# 369/369 [==============================] - 0s 747us/step - loss: 0.2144 - mse: 0.1925 - val_loss: 0.1852 - val_mse: 0.1971
# Epoch 6/50
# 369/369 [==============================] - 0s 688us/step - loss: 0.2085 - mse: 0.1885 - val_loss: 0.1790 - val_mse: 0.1819
# Epoch 7/50
# 369/369 [==============================] - 0s 612us/step - loss: 0.2063 - mse: 0.1872 - val_loss: 0.1733 - val_mse: 0.1776
# Epoch 8/50
# 369/369 [==============================] - 0s 716us/step - loss: 0.2035 - mse: 0.1842 - val_loss: 0.1766 - val_mse: 0.1772
# Epoch 9/50
# 369/369 [==============================] - 0s 764us/step - loss: 0.1999 - mse: 0.1811 - val_loss: 0.1762 - val_mse: 0.1712
# Epoch 10/50
# 369/369 [==============================] - 0s 645us/step - loss: 0.1977 - mse: 0.1785 - val_loss: 0.1696 - val_mse: 0.1720
# Epoch 11/50
# 369/369 [==============================] - 0s 723us/step - loss: 0.1959 - mse: 0.1756 - val_loss: 0.1661 - val_mse: 0.1681
# Epoch 12/50
# 369/369 [==============================] - 0s 734us/step - loss: 0.1943 - mse: 0.1742 - val_loss: 0.1994 - val_mse: 0.1728
# Epoch 13/50
# 369/369 [==============================] - 0s 680us/step - loss: 0.1932 - mse: 0.1716 - val_loss: 0.1735 - val_mse: 0.1621
# Epoch 14/50
# 369/369 [==============================] - 0s 688us/step - loss: 0.1907 - mse: 0.1690 - val_loss: 0.1665 - val_mse: 0.1673
# Epoch 15/50
# 369/369 [==============================] - 0s 685us/step - loss: 0.1899 - mse: 0.1696 - val_loss: 0.1625 - val_mse: 0.1671
# Epoch 16/50
# 369/369 [==============================] - 0s 666us/step - loss: 0.1889 - mse: 0.1668 - val_loss: 0.1827 - val_mse: 0.1578
# Epoch 17/50
# 369/369 [==============================] - 0s 667us/step - loss: 0.1880 - mse: 0.1662 - val_loss: 0.1656 - val_mse: 0.1615
# Epoch 18/50
# 369/369 [==============================] - 0s 747us/step - loss: 0.1873 - mse: 0.1648 - val_loss: 0.1586 - val_mse: 0.1572
# Epoch 19/50
# 369/369 [==============================] - 0s 691us/step - loss: 0.1868 - mse: 0.1639 - val_loss: 0.1586 - val_mse: 0.1494
# Epoch 20/50
# 369/369 [==============================] - 0s 682us/step - loss: 0.1855 - mse: 0.1630 - val_loss: 0.1730 - val_mse: 0.1604
# Epoch 21/50
# 369/369 [==============================] - 0s 791us/step - loss: 0.1851 - mse: 0.1624 - val_loss: 0.1600 - val_mse: 0.1479
# Epoch 22/50
# 369/369 [==============================] - 0s 740us/step - loss: 0.1843 - mse: 0.1618 - val_loss: 0.1568 - val_mse: 0.1504
# Epoch 23/50
# 369/369 [==============================] - 0s 686us/step - loss: 0.1832 - mse: 0.1613 - val_loss: 0.1630 - val_mse: 0.1499
# Epoch 24/50
# 369/369 [==============================] - 0s 748us/step - loss: 0.1837 - mse: 0.1602 - val_loss: 0.1631 - val_mse: 0.1536
# Epoch 25/50
# 369/369 [==============================] - 0s 682us/step - loss: 0.1822 - mse: 0.1606 - val_loss: 0.1536 - val_mse: 0.1466
# Epoch 26/50
# 369/369 [==============================] - 0s 763us/step - loss: 0.1819 - mse: 0.1603 - val_loss: 0.2023 - val_mse: 0.1611
# Epoch 27/50
# 369/369 [==============================] - 0s 705us/step - loss: 0.1819 - mse: 0.1607 - val_loss: 0.1548 - val_mse: 0.1506
# Epoch 28/50
# 369/369 [==============================] - 0s 750us/step - loss: 0.1815 - mse: 0.1586 - val_loss: 0.1594 - val_mse: 0.1550
# Epoch 29/50
# 369/369 [==============================] - 0s 686us/step - loss: 0.1800 - mse: 0.1577 - val_loss: 0.1822 - val_mse: 0.1501
# Epoch 30/50
# 369/369 [==============================] - 0s 771us/step - loss: 0.1801 - mse: 0.1583 - val_loss: 0.1748 - val_mse: 0.1521
# Epoch 31/50
# 369/369 [==============================] - 0s 777us/step - loss: 0.1797 - mse: 0.1585 - val_loss: 0.1488 - val_mse: 0.1444
# Epoch 32/50
# 369/369 [==============================] - 0s 786us/step - loss: 0.1797 - mse: 0.1584 - val_loss: 0.1584 - val_mse: 0.1498
# Epoch 33/50
# 369/369 [==============================] - 0s 891us/step - loss: 0.1793 - mse: 0.1571 - val_loss: 0.1550 - val_mse: 0.1489
# Epoch 34/50
# 369/369 [==============================] - 0s 847us/step - loss: 0.1793 - mse: 0.1569 - val_loss: 0.1532 - val_mse: 0.1447
# Epoch 35/50
# 369/369 [==============================] - 0s 889us/step - loss: 0.1790 - mse: 0.1573 - val_loss: 0.1489 - val_mse: 0.1468
# Epoch 36/50
# 369/369 [==============================] - 0s 630us/step - loss: 0.1792 - mse: 0.1581 - val_loss: 0.1524 - val_mse: 0.1556
# Epoch 37/50
# 369/369 [==============================] - 0s 784us/step - loss: 0.1782 - mse: 0.1561 - val_loss: 0.1532 - val_mse: 0.1461
# Epoch 38/50
# 369/369 [==============================] - 0s 571us/step - loss: 0.1771 - mse: 0.1550 - val_loss: 0.1524 - val_mse: 0.1529
# Epoch 39/50
# 369/369 [==============================] - 0s 711us/step - loss: 0.1781 - mse: 0.1558 - val_loss: 0.1613 - val_mse: 0.1434
# Epoch 40/50
# 369/369 [==============================] - 0s 740us/step - loss: 0.1779 - mse: 0.1556 - val_loss: 0.1553 - val_mse: 0.1426
# Epoch 41/50
# 369/369 [==============================] - 0s 603us/step - loss: 0.1772 - mse: 0.1557 - val_loss: 0.1478 - val_mse: 0.1433
# Epoch 42/50
# 369/369 [==============================] - 0s 583us/step - loss: 0.1772 - mse: 0.1555 - val_loss: 0.1478 - val_mse: 0.1400
# Epoch 43/50
# 369/369 [==============================] - 0s 639us/step - loss: 0.1768 - mse: 0.1545 - val_loss: 0.1560 - val_mse: 0.1418
# Epoch 44/50
# 369/369 [==============================] - 0s 606us/step - loss: 0.1762 - mse: 0.1548 - val_loss: 0.1561 - val_mse: 0.1458
# Epoch 45/50
# 369/369 [==============================] - 0s 685us/step - loss: 0.1764 - mse: 0.1547 - val_loss: 0.2320 - val_mse: 0.1776
# Epoch 46/50
# 369/369 [==============================] - 0s 584us/step - loss: 0.1759 - mse: 0.1546 - val_loss: 0.1648 - val_mse: 0.1470
# Epoch 47/50
# 369/369 [==============================] - 0s 591us/step - loss: 0.1755 - mse: 0.1538 - val_loss: 0.1565 - val_mse: 0.1458
# Epoch 48/50
# 369/369 [==============================] - 0s 578us/step - loss: 0.1760 - mse: 0.1535 - val_loss: 0.1439 - val_mse: 0.1396
# Epoch 49/50
# 369/369 [==============================] - 0s 609us/step - loss: 0.1748 - mse: 0.1529 - val_loss: 0.1540 - val_mse: 0.1432
# Epoch 50/50
# 369/369 [==============================] - 0s 677us/step - loss: 0.1749 - mse: 0.1535 - val_loss: 0.1570 - val_mse: 0.1411

# %%
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.xlabel("epochs")
plt.ylabel("loss/var_loss")
plt.legend()
plt.savefig("14.png")
plt.show()

# %%
plt.plot(history.history['mse'], label = 'train')
plt.plot(history.history['val_mse'], label = 'test')
plt.legend()
plt.xlabel("epochs")
plt.ylabel("mse/var_mse")
plt.savefig("15.png")
plt.show()

# %%
min(history.history['loss']),min(history.history['val_loss']),min(history.history['mse']),min(history.history['val_mse'])
# Out:
# (0.17475570738315582,
#  0.1439233124256134,
#  0.15293239057064056,
#  0.13955838978290558)

# %%
y_predicted = classifier.predict(X_test)

# %%
y_predicted = np.argmax(y_predicted, axis = 1)
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test = np.argmax(y_test, axis = 1)

# %%
test_sum = y_test.sum()*15
predicted_sum = y_predicted.sum()*15

# %%
print("Error Percentage in predicted values is : {} %".format(np.absolute((predicted_sum - test_sum)/test_sum)*100))
# Out:
# Error Percentage in predicted values is : 16.966904063678257 %

# %%
y_train_predicted = classifier.predict(X_train)
y_train_predicted = np.argmax(y_train_predicted, axis = 1)
y_train = np.argmax(y_train, axis = 1)

# %%
f1_score(y_train, y_train_predicted, average = 'weighted')
# Out:
# 0.7167734062275763

# %%
accuracy_score(y_train, y_train_predicted)
# Out:
# 0.7820362294532036

# %%
mean_absolute_error(y_train, y_train_predicted)
# Out:
# 0.5296880241529688

# %%
mean_absolute_error(y_test, y_predicted)
# Out:
# 0.37289915966386555

# %%
accuracy_score(y_test, y_predicted)
# Out:
# 0.8609943977591037

# %%
f1_score(y_test, y_predicted, average = 'weighted')
# Out:
# 0.8179900862366037

# %% [markdown]
# ### Daytime

# %%
daytime_daily_activity_member = day_time_data.groupby(by = [ 'Outdoor Temp (C)','Heat Stage 1 (min)']).count()['Heat Stage 1 (sec)'].unstack()

plt.figure(figsize = (20, 10))

sns.heatmap(daily_activity_member, cmap = 'Oranges')

plt.title('Day Time Outside Temperaturxe vs Heat Stage1 (min)', fontsize = 14)
plt.xlabel('Heat Stage1 (min)', fontsize = 14)
plt.ylabel('Outside Temperature', fontsize = 14)
plt.show()

# %%
reframed_daytime = series_to_supervised(day_time_data[["Outdoor Temp (C)","Heat Stage 1 (min)"]], 12, 1)
reframed_daytime
# Out:
#        var1(t-12)  var2(t-12)  var1(t-11)  var2(t-11)  var1(t-10)  var2(t-10)  \
# 12            5.0        0.00         5.0        0.00         5.2        0.00
# 13            5.0        0.00         5.2        0.00         5.2        2.25
# 14            5.2        0.00         5.2        2.25         5.2        5.00
# 15            5.2        2.25         5.2        5.00         5.2        5.00
# 16            5.2        5.00         5.2        5.00         5.2        5.00
# ...           ...         ...         ...         ...         ...         ...
# 29671        14.4        0.00        14.9        0.00        14.9        0.00
# 29672        14.9        0.00        14.9        0.00        14.9        0.00
# 29673        14.9        0.00        14.9        0.00        14.9        0.00
# 29674        14.9        0.00        14.9        0.00        14.9        0.00
# 29675        14.9        0.00        14.9        0.00        14.9        0.00
#
#        var1(t-9)  var2(t-9)  var1(t-8)  var2(t-8)  ...  var1(t-4)  var2(t-4)  \
# 12           5.2       2.25        5.2       5.00  ...        5.4        0.0
# 13           5.2       5.00        5.2       5.00  ...        5.4        0.0
# 14           5.2       5.00        5.2       5.00  ...        5.4        0.0
# 15           5.2       5.00        5.2       0.75  ...        5.4        0.0
# 16           5.2       0.75        5.4       0.00  ...        5.4        0.0
# ...          ...        ...        ...        ...  ...        ...        ...
# 29671       14.9       0.00       14.9       0.00  ...       15.2        0.0
# 29672       14.9       0.00       14.9       0.00  ...       15.2        0.0
# 29673       14.9       0.00       14.9       0.00  ...       15.2        0.0
# 29674       14.9       0.00       15.2       0.00  ...       15.2        0.0
# 29675       15.2       0.00       15.2       0.00  ...       15.2        0.0
#
#        var1(t-3)  var2(t-3)  var1(t-2)  var2(t-2)  var1(t-1)  var2(t-1)  \
# 12           5.4        0.0        5.4       0.00        5.4       0.00
# 13           5.4        0.0        5.4       0.00        5.4       0.00
# 14           5.4        0.0        5.4       0.00        5.4       0.00
# 15           5.4        0.0        5.4       0.00        5.3       4.25
# 16           5.4        0.0        5.3       4.25        5.3       5.00
# ...          ...        ...        ...        ...        ...        ...
# 29671       15.2        0.0       15.2       0.00       15.2       0.00
# 29672       15.2        0.0       15.2       0.00       15.2       0.00
# 29673       15.2        0.0       15.2       0.00       15.7       0.00
# 29674       15.2        0.0       15.7       0.00       15.7       0.00
# 29675       15.7        0.0       15.7       0.00       15.7       0.00
#
#        var1(t)  var2(t)
# 12         5.4     0.00
# 13         5.4     0.00
# 14         5.3     4.25
# 15         5.3     5.00
# 16         5.3     1.50
# ...        ...      ...
# 29671     15.2     0.00
# 29672     15.7     0.00
# 29673     15.7     0.00
# 29674     15.7     0.00
# 29675     15.7     0.00
#
# [14726 rows x 26 columns]

# %%
y_auxHeat = reframed_daytime['var2(t)']
#y_auxHeat = to_categorical(y_auxHeat)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(np.array(y_auxHeat).reshape(-1,1))
y_auxHeat = sc.transform(np.array(y_auxHeat).reshape(-1,1))

X = reframed_daytime.drop(labels = ['var2(t)'], axis = 1)
sc = StandardScaler()
sc.fit(X)
X = sc.transform(X)
#X_train = X.iloc[:23584,]
X_train = X[:11924,]
y_train = y_auxHeat[:11924,]
#X_test = X.iloc[23584:]
X_test = X[11924:]
y_test = y_auxHeat[11924:]
#X_train = X_train.values
#X_test = X_test.values

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model    
model = linear_model.LinearRegression()

model.fit(X,y_auxHeat)
predict_y = model.predict(X)

r2_score(predict_y,y_auxHeat)
# Out:
# 0.35104425698545516

# %%
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu', input_dim = 25))

# Adding the second hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'normal', activation = 'linear'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'mean_absolute_error', metrics = ['mse']) 

# Fitting the ANN to the Training set
history = classifier.fit(X_train, y_train, validation_data = (X_test, y_test), batch_size = 64, epochs = 50, shuffle = True)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 0s 1ms/step - loss: 0.6173 - mse: 0.6971 - val_loss: 0.4024 - val_mse: 0.3878
# Epoch 2/50
# 187/187 [==============================] - 0s 745us/step - loss: 0.3740 - mse: 0.3651 - val_loss: 0.3092 - val_mse: 0.3053
# Epoch 3/50
# 187/187 [==============================] - 0s 844us/step - loss: 0.3442 - mse: 0.3336 - val_loss: 0.2808 - val_mse: 0.2822
# Epoch 4/50
# 187/187 [==============================] - 0s 766us/step - loss: 0.3250 - mse: 0.3208 - val_loss: 0.2560 - val_mse: 0.2716
# Epoch 5/50
# 187/187 [==============================] - 0s 795us/step - loss: 0.3105 - mse: 0.3106 - val_loss: 0.2428 - val_mse: 0.2659
# Epoch 6/50
# 187/187 [==============================] - 0s 745us/step - loss: 0.2945 - mse: 0.3003 - val_loss: 0.2449 - val_mse: 0.2651
# Epoch 7/50
# 187/187 [==============================] - 0s 703us/step - loss: 0.2850 - mse: 0.2957 - val_loss: 0.2306 - val_mse: 0.2587
# Epoch 8/50
# 187/187 [==============================] - 0s 701us/step - loss: 0.2742 - mse: 0.2886 - val_loss: 0.2151 - val_mse: 0.2502
# Epoch 9/50
# 187/187 [==============================] - 0s 781us/step - loss: 0.2662 - mse: 0.2823 - val_loss: 0.2097 - val_mse: 0.2456
# Epoch 10/50
# 187/187 [==============================] - 0s 927us/step - loss: 0.2631 - mse: 0.2806 - val_loss: 0.2145 - val_mse: 0.2458
# Epoch 11/50
# 187/187 [==============================] - 0s 771us/step - loss: 0.2586 - mse: 0.2770 - val_loss: 0.1949 - val_mse: 0.2382
# Epoch 12/50
# 187/187 [==============================] - 0s 840us/step - loss: 0.2548 - mse: 0.2750 - val_loss: 0.2117 - val_mse: 0.2422
# Epoch 13/50
# 187/187 [==============================] - 0s 839us/step - loss: 0.2537 - mse: 0.2749 - val_loss: 0.1989 - val_mse: 0.2389
# Epoch 14/50
# 187/187 [==============================] - 0s 785us/step - loss: 0.2516 - mse: 0.2714 - val_loss: 0.1994 - val_mse: 0.2343
# Epoch 15/50
# 187/187 [==============================] - 0s 736us/step - loss: 0.2483 - mse: 0.2665 - val_loss: 0.1967 - val_mse: 0.2380
# Epoch 16/50
# 187/187 [==============================] - 0s 760us/step - loss: 0.2485 - mse: 0.2672 - val_loss: 0.2004 - val_mse: 0.2363
# Epoch 17/50
# 187/187 [==============================] - 0s 808us/step - loss: 0.2427 - mse: 0.2617 - val_loss: 0.1995 - val_mse: 0.2353
# Epoch 18/50
# 187/187 [==============================] - 0s 936us/step - loss: 0.2436 - mse: 0.2603 - val_loss: 0.1857 - val_mse: 0.2247
# Epoch 19/50
# 187/187 [==============================] - 0s 804us/step - loss: 0.2408 - mse: 0.2584 - val_loss: 0.1858 - val_mse: 0.2283
# Epoch 20/50
# 187/187 [==============================] - 0s 714us/step - loss: 0.2407 - mse: 0.2568 - val_loss: 0.1865 - val_mse: 0.2256
# Epoch 21/50
# 187/187 [==============================] - 0s 829us/step - loss: 0.2407 - mse: 0.2567 - val_loss: 0.1863 - val_mse: 0.2243
# Epoch 22/50
# 187/187 [==============================] - 0s 867us/step - loss: 0.2379 - mse: 0.2557 - val_loss: 0.1854 - val_mse: 0.2235
# Epoch 23/50
# 187/187 [==============================] - 0s 815us/step - loss: 0.2368 - mse: 0.2519 - val_loss: 0.1824 - val_mse: 0.2202
# Epoch 24/50
# 187/187 [==============================] - 0s 793us/step - loss: 0.2377 - mse: 0.2562 - val_loss: 0.1842 - val_mse: 0.2174
# Epoch 25/50
# 187/187 [==============================] - 0s 803us/step - loss: 0.2347 - mse: 0.2515 - val_loss: 0.1810 - val_mse: 0.2248
# Epoch 26/50
# 187/187 [==============================] - 0s 868us/step - loss: 0.2344 - mse: 0.2525 - val_loss: 0.1749 - val_mse: 0.2168
# Epoch 27/50
# 187/187 [==============================] - 0s 752us/step - loss: 0.2341 - mse: 0.2504 - val_loss: 0.1771 - val_mse: 0.2163
# Epoch 28/50
# 187/187 [==============================] - 0s 727us/step - loss: 0.2335 - mse: 0.2492 - val_loss: 0.1839 - val_mse: 0.2220
# Epoch 29/50
# 187/187 [==============================] - 0s 835us/step - loss: 0.2325 - mse: 0.2488 - val_loss: 0.1812 - val_mse: 0.2129
# Epoch 30/50
# 187/187 [==============================] - 0s 825us/step - loss: 0.2308 - mse: 0.2471 - val_loss: 0.1746 - val_mse: 0.2144
# Epoch 31/50
# 187/187 [==============================] - 0s 824us/step - loss: 0.2318 - mse: 0.2471 - val_loss: 0.1772 - val_mse: 0.2188
# Epoch 32/50
# 187/187 [==============================] - 0s 770us/step - loss: 0.2311 - mse: 0.2462 - val_loss: 0.1738 - val_mse: 0.2172
# Epoch 33/50
# 187/187 [==============================] - 0s 835us/step - loss: 0.2312 - mse: 0.2470 - val_loss: 0.1782 - val_mse: 0.2184
# Epoch 34/50
# 187/187 [==============================] - 0s 789us/step - loss: 0.2304 - mse: 0.2463 - val_loss: 0.1807 - val_mse: 0.2210
# Epoch 35/50
# 187/187 [==============================] - 0s 814us/step - loss: 0.2301 - mse: 0.2476 - val_loss: 0.1834 - val_mse: 0.2168
# Epoch 36/50
# 187/187 [==============================] - 0s 768us/step - loss: 0.2286 - mse: 0.2474 - val_loss: 0.1765 - val_mse: 0.2162
# Epoch 37/50
# 187/187 [==============================] - 0s 680us/step - loss: 0.2272 - mse: 0.2431 - val_loss: 0.1765 - val_mse: 0.2146
# Epoch 38/50
# 187/187 [==============================] - 0s 676us/step - loss: 0.2263 - mse: 0.2430 - val_loss: 0.1865 - val_mse: 0.2134
# Epoch 39/50
# 187/187 [==============================] - 0s 640us/step - loss: 0.2261 - mse: 0.2436 - val_loss: 0.1750 - val_mse: 0.2145
# Epoch 40/50
# 187/187 [==============================] - 0s 665us/step - loss: 0.2261 - mse: 0.2420 - val_loss: 0.1756 - val_mse: 0.2199
# Epoch 41/50
# 187/187 [==============================] - 0s 788us/step - loss: 0.2271 - mse: 0.2446 - val_loss: 0.1751 - val_mse: 0.2099
# Epoch 42/50
# 187/187 [==============================] - 0s 881us/step - loss: 0.2244 - mse: 0.2407 - val_loss: 0.1702 - val_mse: 0.2107
# Epoch 43/50
# 187/187 [==============================] - 0s 910us/step - loss: 0.2250 - mse: 0.2413 - val_loss: 0.1714 - val_mse: 0.2178
# Epoch 44/50
# 187/187 [==============================] - 0s 984us/step - loss: 0.2260 - mse: 0.2436 - val_loss: 0.3024 - val_mse: 0.2751
# Epoch 45/50
# 187/187 [==============================] - 0s 712us/step - loss: 0.2259 - mse: 0.2454 - val_loss: 0.1734 - val_mse: 0.2197
# Epoch 46/50
# 187/187 [==============================] - 0s 735us/step - loss: 0.2244 - mse: 0.2423 - val_loss: 0.1693 - val_mse: 0.2107
# Epoch 47/50
# 187/187 [==============================] - 0s 634us/step - loss: 0.2232 - mse: 0.2405 - val_loss: 0.1713 - val_mse: 0.2171
# Epoch 48/50
# 187/187 [==============================] - 0s 674us/step - loss: 0.2242 - mse: 0.2433 - val_loss: 0.1745 - val_mse: 0.2171
# Epoch 49/50
# 187/187 [==============================] - 0s 679us/step - loss: 0.2234 - mse: 0.2428 - val_loss: 0.1722 - val_mse: 0.2152
# Epoch 50/50
# 187/187 [==============================] - 0s 659us/step - loss: 0.2223 - mse: 0.2391 - val_loss: 0.1727 - val_mse: 0.2116

# %%
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend()
plt.xlabel("epochs")
plt.ylabel("loss/var_loss")
plt.savefig("16.png")
plt.show()

# %%
plt.plot(history.history['mse'], label = 'train')
plt.plot(history.history['val_mse'], label = 'test')
plt.legend()
plt.xlabel("epochs")
plt.ylabel("mse/var_mse")
plt.savefig("17.png")
plt.show()

# %%
min(history.history['loss']),min(history.history['val_loss']),min(history.history['mse']),min(history.history['val_mse'])
# Out:
# (0.2223229557275772,
#  0.16932231187820435,
#  0.239106684923172,
#  0.20991259813308716)

# %%
y_predicted = classifier.predict(X_test)

# %%
y_predicted = np.argmax(y_predicted, axis = 1)

# %%
y_test = np.argmax(y_test, axis = 1)

# %%
test_sum = y_test.sum()*15
predicted_sum = y_predicted.sum()*15
print("Error Percentage in predicted values is : {} %".format(np.absolute((predicted_sum - test_sum)/test_sum)*100))
# Out:
# Error Percentage in predicted values is : 19.312945119396733 %

# %%
y_train_predicted = classifier.predict(X_train)
y_train_predicted = np.argmax(y_train_predicted, axis = 1)
y_train = np.argmax(y_train, axis = 1)

# %%
f1_score(y_train, y_train_predicted, average = 'weighted')
# Out:
# 0.7138443423481241

# %%
accuracy_score(y_train, y_train_predicted)
# Out:
# 0.7800234820530023

# %%
mean_absolute_error(y_train, y_train_predicted)
# Out:
# 0.5449513586044952

# %%
mean_absolute_error(y_test, y_predicted)
# Out:
# 0.3707983193277311

# %%
accuracy_score(y_test, y_predicted)
# Out:
# 0.8599439775910365

# %%
f1_score(y_test, y_predicted, average = 'weighted')
# Out:
# 0.8155656969467757

# %% [markdown]
# ### Night

# %%
night_daily_activity_member = night_data.groupby(by = [ 'Outdoor Temp (C)','Heat Stage 1 (min)']).count()['Heat Stage 1 (sec)'].unstack()

plt.figure(figsize = (20, 10))

sns.heatmap(night_daily_activity_member, cmap = 'Oranges')

plt.title('Night Outside Temperaturxe vs Current Humidity Heatmap', fontsize = 14)
plt.ylabel('Heat Stage1 (min)', fontsize = 14)
plt.xlabel('Outside Temperature', fontsize = 14)
plt.show()

# %%
reframed_night_data = series_to_supervised(night_data[["Outdoor Temp (C)","Heat Stage 1 (min)"]], 12, 1)
reframed_night_data
# Out:
#        var1(t-12)  var2(t-12)  var1(t-11)  var2(t-11)  var1(t-10)  var2(t-10)  \
# 74            3.4         3.5         3.4         5.0         3.4         5.0
# 75            3.4         5.0         3.4         5.0         3.4         1.5
# 76            3.4         5.0         3.4         1.5         3.4         0.0
# 77            3.4         1.5         3.4         0.0         3.4         0.0
# 78            3.4         0.0         3.4         0.0         3.4         0.0
# ...           ...         ...         ...         ...         ...         ...
# 29577         4.1         0.0         4.1         3.0         4.1         5.0
# 29578         4.1         3.0         4.1         5.0         4.1         2.0
# 29579         4.1         5.0         4.1         2.0         4.1         0.0
# 29580         4.1         2.0         4.1         0.0         3.7         0.0
# 29581         4.1         0.0         3.7         0.0         3.7         0.0
#
#        var1(t-9)  var2(t-9)  var1(t-8)  var2(t-8)  ...  var1(t-4)  var2(t-4)  \
# 74           3.4       1.50        3.4       0.00  ...        3.4       5.00
# 75           3.4       0.00        3.4       0.00  ...        3.4       5.00
# 76           3.4       0.00        3.4       0.00  ...        3.4       0.00
# 77           3.4       0.00        3.4       1.25  ...        3.4       0.00
# 78           3.4       1.25        3.4       5.00  ...        2.6       0.00
# ...          ...        ...        ...        ...  ...        ...        ...
# 29577        4.1       2.00        4.1       0.00  ...        3.7       3.25
# 29578        4.1       0.00        3.7       0.00  ...        3.7       5.00
# 29579        3.7       0.00        3.7       0.00  ...        3.7       3.50
# 29580        3.7       0.00        3.7       0.00  ...        3.4       0.00
# 29581        3.7       0.00        3.7       3.25  ...        3.4       0.00
#
#        var1(t-3)  var2(t-3)  var1(t-2)  var2(t-2)  var1(t-1)  var2(t-1)  \
# 74           3.4       5.00        3.4       0.00        3.4       0.00
# 75           3.4       0.00        3.4       0.00        2.6       0.00
# 76           3.4       0.00        2.6       0.00        2.6       1.75
# 77           2.6       0.00        2.6       1.75        2.6       5.00
# 78           2.6       1.75        2.6       5.00        2.6       5.00
# ...          ...        ...        ...        ...        ...        ...
# 29577        3.7       5.00        3.7       3.50        3.4       0.00
# 29578        3.7       3.50        3.4       0.00        3.4       0.00
# 29579        3.4       0.00        3.4       0.00        3.4       0.00
# 29580        3.4       0.00        3.4       0.00        3.4       0.00
# 29581        3.4       0.00        3.4       0.00        3.4       1.25
#
#        var1(t)  var2(t)
# 74         2.6     0.00
# 75         2.6     1.75
# 76         2.6     5.00
# 77         2.6     5.00
# 78         2.6     1.00
# ...        ...      ...
# 29577      3.4     0.00
# 29578      3.4     0.00
# 29579      3.4     0.00
# 29580      3.4     1.25
# 29581      3.4     5.00
#
# [15840 rows x 26 columns]

# %%
y_auxHeat = reframed_night_data['var2(t)']

# %%
y_auxHeat = reframed_night_data['var2(t)']
#y_auxHeat = to_categorical(y_auxHeat)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(np.array(y_auxHeat).reshape(-1,1))
y_auxHeat = sc.transform(np.array(y_auxHeat).reshape(-1,1))

X = reframed_night_data.drop(labels = ['var2(t)'], axis = 1)
sc = StandardScaler()
sc.fit(X)
X = sc.transform(X)
#X_train = X.iloc[:23584,]
X_train = X[:12725,]
y_train = y_auxHeat[:12725,]
#X_test = X.iloc[23584:]
X_test = X[12725:]
y_test = y_auxHeat[12725:]
#X_train = X_train.values
#X_test = X_test.values

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model    
model = linear_model.LinearRegression()

model.fit(X,y_auxHeat)
predict_y = model.predict(X)

r2_score(predict_y,y_auxHeat)
# Out:
# 0.6803154411811485

# %%
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu', input_dim = 25))

# Adding the second hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'normal', activation = 'linear'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'mean_absolute_error', metrics = ['mse']) 

# Fitting the ANN to the Training set
history = classifier.fit(X_train, y_train, validation_data = (X_test, y_test), batch_size = 64, epochs = 50, shuffle = True)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 0s 1ms/step - loss: 0.6073 - mse: 0.6678 - val_loss: 0.3573 - val_mse: 0.3450
# Epoch 2/50
# 187/187 [==============================] - 0s 828us/step - loss: 0.3685 - mse: 0.3535 - val_loss: 0.2874 - val_mse: 0.2865
# Epoch 3/50
# 187/187 [==============================] - 0s 833us/step - loss: 0.3416 - mse: 0.3297 - val_loss: 0.2728 - val_mse: 0.2750
# Epoch 4/50
# 187/187 [==============================] - 0s 715us/step - loss: 0.3208 - mse: 0.3134 - val_loss: 0.2456 - val_mse: 0.2611
# Epoch 5/50
# 187/187 [==============================] - 0s 813us/step - loss: 0.3033 - mse: 0.3031 - val_loss: 0.2160 - val_mse: 0.2511
# Epoch 6/50
# 187/187 [==============================] - 0s 808us/step - loss: 0.2873 - mse: 0.2949 - val_loss: 0.2171 - val_mse: 0.2506
# Epoch 7/50
# 187/187 [==============================] - 0s 916us/step - loss: 0.2769 - mse: 0.2875 - val_loss: 0.2020 - val_mse: 0.2472
# Epoch 8/50
# 187/187 [==============================] - 0s 826us/step - loss: 0.2695 - mse: 0.2852 - val_loss: 0.2011 - val_mse: 0.2442
# Epoch 9/50
# 187/187 [==============================] - 0s 825us/step - loss: 0.2644 - mse: 0.2804 - val_loss: 0.1967 - val_mse: 0.2431
# Epoch 10/50
# 187/187 [==============================] - 0s 767us/step - loss: 0.2612 - mse: 0.2789 - val_loss: 0.2007 - val_mse: 0.2411
# Epoch 11/50
# 187/187 [==============================] - 0s 916us/step - loss: 0.2570 - mse: 0.2765 - val_loss: 0.1945 - val_mse: 0.2406
# Epoch 12/50
# 187/187 [==============================] - 0s 731us/step - loss: 0.2543 - mse: 0.2733 - val_loss: 0.1876 - val_mse: 0.2347
# Epoch 13/50
# 187/187 [==============================] - 0s 832us/step - loss: 0.2527 - mse: 0.2728 - val_loss: 0.1870 - val_mse: 0.2357
# Epoch 14/50
# 187/187 [==============================] - 0s 791us/step - loss: 0.2503 - mse: 0.2708 - val_loss: 0.1973 - val_mse: 0.2401
# Epoch 15/50
# 187/187 [==============================] - 0s 949us/step - loss: 0.2495 - mse: 0.2706 - val_loss: 0.1863 - val_mse: 0.2287
# Epoch 16/50
# 187/187 [==============================] - 0s 804us/step - loss: 0.2483 - mse: 0.2702 - val_loss: 0.1836 - val_mse: 0.2303
# Epoch 17/50
# 187/187 [==============================] - 0s 799us/step - loss: 0.2457 - mse: 0.2684 - val_loss: 0.1874 - val_mse: 0.2281
# Epoch 18/50
# 187/187 [==============================] - 0s 834us/step - loss: 0.2463 - mse: 0.2654 - val_loss: 0.1820 - val_mse: 0.2271
# Epoch 19/50
# 187/187 [==============================] - 0s 843us/step - loss: 0.2440 - mse: 0.2638 - val_loss: 0.1798 - val_mse: 0.2258
# Epoch 20/50
# 187/187 [==============================] - 0s 838us/step - loss: 0.2408 - mse: 0.2620 - val_loss: 0.1855 - val_mse: 0.2291
# Epoch 21/50
# 187/187 [==============================] - 0s 928us/step - loss: 0.2416 - mse: 0.2627 - val_loss: 0.1801 - val_mse: 0.2281
# Epoch 22/50
# 187/187 [==============================] - 0s 777us/step - loss: 0.2395 - mse: 0.2612 - val_loss: 0.1839 - val_mse: 0.2270
# Epoch 23/50
# 187/187 [==============================] - 0s 806us/step - loss: 0.2402 - mse: 0.2606 - val_loss: 0.1902 - val_mse: 0.2280
# Epoch 24/50
# 187/187 [==============================] - 0s 829us/step - loss: 0.2383 - mse: 0.2591 - val_loss: 0.1795 - val_mse: 0.2214
# Epoch 25/50
# 187/187 [==============================] - 0s 823us/step - loss: 0.2357 - mse: 0.2584 - val_loss: 0.1846 - val_mse: 0.2222
# Epoch 26/50
# 187/187 [==============================] - 0s 937us/step - loss: 0.2358 - mse: 0.2553 - val_loss: 0.1767 - val_mse: 0.2154
# Epoch 27/50
# 187/187 [==============================] - 0s 881us/step - loss: 0.2366 - mse: 0.2576 - val_loss: 0.1804 - val_mse: 0.2209
# Epoch 28/50
# 187/187 [==============================] - 0s 876us/step - loss: 0.2346 - mse: 0.2543 - val_loss: 0.1787 - val_mse: 0.2204
# Epoch 29/50
# 187/187 [==============================] - 0s 861us/step - loss: 0.2336 - mse: 0.2540 - val_loss: 0.1830 - val_mse: 0.2207
# Epoch 30/50
# 187/187 [==============================] - 0s 772us/step - loss: 0.2333 - mse: 0.2532 - val_loss: 0.1861 - val_mse: 0.2192
# Epoch 31/50
# 187/187 [==============================] - 0s 966us/step - loss: 0.2335 - mse: 0.2519 - val_loss: 0.1775 - val_mse: 0.2176
# Epoch 32/50
# 187/187 [==============================] - 0s 904us/step - loss: 0.2313 - mse: 0.2492 - val_loss: 0.1741 - val_mse: 0.2185
# Epoch 33/50
# 187/187 [==============================] - 0s 880us/step - loss: 0.2324 - mse: 0.2531 - val_loss: 0.1754 - val_mse: 0.2251
# Epoch 34/50
# 187/187 [==============================] - 0s 789us/step - loss: 0.2316 - mse: 0.2530 - val_loss: 0.1797 - val_mse: 0.2176
# Epoch 35/50
# 187/187 [==============================] - 0s 745us/step - loss: 0.2317 - mse: 0.2523 - val_loss: 0.1833 - val_mse: 0.2203
# Epoch 36/50
# 187/187 [==============================] - 0s 1ms/step - loss: 0.2311 - mse: 0.2519 - val_loss: 0.1710 - val_mse: 0.2153
# Epoch 37/50
# 187/187 [==============================] - 0s 789us/step - loss: 0.2295 - mse: 0.2492 - val_loss: 0.1785 - val_mse: 0.2133
# Epoch 38/50
# 187/187 [==============================] - 0s 655us/step - loss: 0.2287 - mse: 0.2495 - val_loss: 0.1736 - val_mse: 0.2149
# Epoch 39/50
# 187/187 [==============================] - 0s 775us/step - loss: 0.2275 - mse: 0.2474 - val_loss: 0.1723 - val_mse: 0.2120
# Epoch 40/50
# 187/187 [==============================] - 0s 697us/step - loss: 0.2277 - mse: 0.2461 - val_loss: 0.1749 - val_mse: 0.2130
# Epoch 41/50
# 187/187 [==============================] - 0s 625us/step - loss: 0.2263 - mse: 0.2470 - val_loss: 0.1727 - val_mse: 0.2080
# Epoch 42/50
# 187/187 [==============================] - 0s 713us/step - loss: 0.2274 - mse: 0.2475 - val_loss: 0.1767 - val_mse: 0.2123
# Epoch 43/50
# 187/187 [==============================] - 0s 717us/step - loss: 0.2267 - mse: 0.2425 - val_loss: 0.1767 - val_mse: 0.2226
# Epoch 44/50
# 187/187 [==============================] - 0s 711us/step - loss: 0.2264 - mse: 0.2457 - val_loss: 0.1698 - val_mse: 0.2144
# Epoch 45/50
# 187/187 [==============================] - 0s 800us/step - loss: 0.2249 - mse: 0.2445 - val_loss: 0.1749 - val_mse: 0.2211
# Epoch 46/50
# 187/187 [==============================] - 0s 851us/step - loss: 0.2247 - mse: 0.2457 - val_loss: 0.1723 - val_mse: 0.2094
# Epoch 47/50
# 187/187 [==============================] - 0s 779us/step - loss: 0.2246 - mse: 0.2431 - val_loss: 0.1707 - val_mse: 0.2096
# Epoch 48/50
# 187/187 [==============================] - 0s 722us/step - loss: 0.2230 - mse: 0.2410 - val_loss: 0.1698 - val_mse: 0.2181
# Epoch 49/50
# 187/187 [==============================] - 0s 728us/step - loss: 0.2233 - mse: 0.2442 - val_loss: 0.1732 - val_mse: 0.2123
# Epoch 50/50
# 187/187 [==============================] - 0s 881us/step - loss: 0.2236 - mse: 0.2418 - val_loss: 0.1748 - val_mse: 0.2114

# %%
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'test')
plt.legend()
plt.xlabel("epochs")
plt.ylabel("loss/var_loss")
plt.savefig("18.png")
plt.show()

# %%
plt.plot(history.history['mse'], label = 'train')
plt.plot(history.history['val_mse'], label = 'test')
plt.legend()
plt.xlabel("epochs")
plt.ylabel("mse/var_mse")
plt.savefig("19.png")
plt.show()

# %%
min(history.history['loss']),min(history.history['val_loss']),min(history.history['mse']),min(history.history['val_mse'])
# Out:
# (0.22302459180355072,
#  0.1697734296321869,
#  0.24100752174854279,
#  0.20797820389270782)

# %%
y_predicted = classifier.predict(X_test)

# %%
y_predicted = np.argmax(y_predicted, axis = 1)
y_predicted
# Out:
# array([5, 3, 0, ..., 0, 0, 5], dtype=int64)

# %%
y_test = np.argmax(y_test, axis = 1)

# %%
test_sum = y_test.sum()*15
predicted_sum = y_predicted.sum()*15
print("Error Percentage in predicted values is : {} %".format(np.absolute((predicted_sum - test_sum)/test_sum)*100))
# Out:
# Error Percentage in predicted values is : 0.019135093761959435 %

# %%
y_train_predicted = classifier.predict(X_train)
y_train_predicted = np.argmax(y_train_predicted, axis = 1)
y_train = np.argmax(y_train, axis = 1)

# %%
f1_score(y_train, y_train_predicted, average = 'weighted')
# Out:
# 0.7297452265755869

# %%
accuracy_score(y_train, y_train_predicted)
# Out:
# 0.76762278978389

# %%
mean_absolute_error(y_train, y_train_predicted)
# Out:
# 0.44275049115913556

# %%
accuracy_score(y_test, y_predicted)
# Out:
# 0.780886513674945

# %%
f1_score(y_test, y_predicted, average = 'weighted')
# Out:
# 0.7537842519033935
