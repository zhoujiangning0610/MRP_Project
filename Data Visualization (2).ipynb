# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

from datetime import datetime as dt

# %%
df = pd.read_excel('Clean_Data.xlsx')

# %%
df.head()
# Out:
#         Date      Time             DateTime System Setting   System Mode  \
# 0 2020-12-10  12:50:00  2020/12/10 12:50:00           heat       heatOff
# 1 2020-12-10  12:55:00  2020/12/10 12:55:00           heat       heatOff
# 2 2020-12-10  13:00:00  2020/12/10 13:00:00           heat       heatOff
# 3 2020-12-10  13:05:00  2020/12/10 13:05:00           heat       heatOff
# 4 2020-12-10  13:10:00  2020/12/10 13:10:00           heat  heatStage1On
#
#   Calendar Event Program Mode  Cool Set Temp (C)  Heat Set Temp (C)  \
# 0           auto         Home               21.0               21.0
# 1           auto         Home               21.0               21.0
# 2           auto         Home               21.0               21.0
# 3           auto         Home               21.0               21.0
# 4           auto         Home               21.0               21.0
#
#    Current Temp (C)  ...  Thermostat Humidity (%RH)  Thermostat Motion  \
# 0              21.3  ...                       30.0                1.0
# 1              21.1  ...                       32.0                1.0
# 2              20.9  ...                       32.0                0.0
# 3              20.7  ...                       33.0                0.0
# 4              20.6  ...                       33.0                1.0
#
#    Bedroom (C)  Bedroom2  3rd floor landing (C)  3rd floor landing2  \
# 0         21.6       0.0                   20.9                 0.0
# 1         21.6       0.0                   20.9                 0.0
# 2         21.6       0.0                   20.8                 0.0
# 3         21.6       0.0                   20.8                 0.0
# 4         21.6       0.0                   20.8                 0.0
#
#    3rd floor room (C)  3rd floor room2  Basement (C)  Basement2
# 0                21.0              0.0          22.8        0.0
# 1                20.9              0.0          22.7        1.0
# 2                20.8              0.0          22.7        1.0
# 3                20.8              0.0          22.8        0.0
# 4                20.8              0.0          22.8        0.0
#
# [5 rows x 27 columns]

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
df['Month'] = pd.DatetimeIndex(df['DateTime']).month

# %%
df['DayOfWeek'] = pd.DatetimeIndex(df['DateTime']).dayofweek

# %%
df['HourofDay'] = pd.DatetimeIndex(df['DateTime']).hour

# %%
df['Day'] = pd.DatetimeIndex(df['DateTime']).day

# %%
print(len(df))
# Out:
# 29676

# %%
for i in range(len(df)):
    if df['Month'][i] == 12:
        df['Month'][i] = 'December'
    elif df['Month'][i] == 1:
        df['Month'][i] = 'January'
    elif df['Month'][i] == 2:
        df['Month'][i] = 'February'
    else:
        df['Month'][i] = 'March'
# Out:
# <ipython-input-12-232888a3e9f3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'][i] = 'December'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-12-232888a3e9f3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'][i] = 'January'
# <ipython-input-12-232888a3e9f3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'][i] = 'February'
# <ipython-input-12-232888a3e9f3>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'][i] = 'March'

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot(data = df[df['Heat Stage 1 (sec)'] == 300], x = 'Month', color = 'steelblue', order = ['December','January','February','March'])
maxHeatUsage.set_xlabel('Month', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 15)
plt.title('Heat Usage & Month', fontsize = 20)
plt.savefig("Figure1.png")
plt.show()

# %%
df[["Outdoor Temp (C)","Month"]]
# Out:
#        Outdoor Temp (C)     Month
# 0                   5.0  December
# 1                   5.0  December
# 2                   5.2  December
# 3                   5.2  December
# 4                   5.2  December
# ...                 ...       ...
# 29671              15.2     March
# 29672              15.7     March
# 29673              15.7     March
# 29674              15.7     March
# 29675              15.7     March
#
# [29676 rows x 2 columns]

# %%
df[["Outdoor Temp (C)","Month"]].groupby("Month").mean().values.reshape(1,-1)
# Out:
# array([[-0.90022646, -5.57671131, -3.21303763,  1.14746232]])

# %%
plt.figure(figsize = (15, 10))
plt.bar(df[["Outdoor Temp (C)","Month"]].groupby("Month").mean().index,df[["Outdoor Temp (C)","Month"]].groupby("Month").mean().values.reshape(1,-1)[0])
# maxHeatUsage = sns.countplot(data = df[["Outdoor Temp (C)","Month"]],x ="Month",  color = 'steelblue', order = ['December','January','February','March'])
plt.xlabel('Month', fontsize = 20)
plt.ylabel('Average Outdoor temp', fontsize = 15)
plt.title('Outdoor Temp & Month', fontsize = 20)
plt.savefig("Figure10.png")
plt.show()

# %%
for i in range(len(df)):
    if df['DayOfWeek'][i] == 0:
        df['DayOfWeek'][i] = 'Monday'
    elif df['DayOfWeek'][i] == 1:
        df['DayOfWeek'][i] = 'Tuesday'
    elif df['DayOfWeek'][i] == 2:
        df['DayOfWeek'][i] = 'Wednesday'
    elif df['DayOfWeek'][i] == 3:
        df['DayOfWeek'][i] = 'Thursday'
    elif df['DayOfWeek'][i] == 4:
        df['DayOfWeek'][i] = 'Friday'
    elif df['DayOfWeek'][i] == 5:
        df['DayOfWeek'][i] = 'Saturday'
    else:
        df['DayOfWeek'][i] = 'Sunday'
# Out:
# <ipython-input-16-076d769337bf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Thursday'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-16-076d769337bf>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Friday'
# <ipython-input-16-076d769337bf>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Saturday'
# <ipython-input-16-076d769337bf>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Sunday'
# <ipython-input-16-076d769337bf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Monday'
# <ipython-input-16-076d769337bf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Tuesday'
# <ipython-input-16-076d769337bf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'][i] = 'Wednesday'

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot(data = df[df['Heat Stage 1 (sec)'] == 300], x = 'DayOfWeek', color = 'steelblue', order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
maxHeatUsage.set_xlabel('Day of Week', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 15)
plt.title('Heat Usage by Day of Week', fontsize = 20)
plt.savefig("figure2.png")
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot(data = df[["Outdoor Temp (C)","DayOfWeek"]], x = 'DayOfWeek', color = 'steelblue', order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
maxHeatUsage.set_xlabel('Day of Week', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Outdoor temperature', fontsize = 15)
plt.title('Heat Usage by Day of Week', fontsize = 20)
plt.savefig("figure2.png")
plt.show()

# %%
plt.figure(figsize = (20, 15))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot( data = df[df['Heat Stage 1 (sec)'] == 300], x = 'HourofDay', color = 'steelblue')
maxHeatUsage.set_xlabel('Hour of Day', fontsize = 25)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 20)
plt.title('Heat Usage by Hour of Day', fontsize = 25)
plt.savefig("figure3.png")
plt.show()

# %%
plt.figure(figsize = (15, 10))
plt.bar(df[["Outdoor Temp (C)","HourofDay"]].groupby("HourofDay").mean().index,df[["Outdoor Temp (C)","HourofDay"]].groupby("HourofDay").mean().values.reshape(1,-1)[0])

plt.xlabel('Hour of Day', fontsize = 20)
plt.ylabel('Average Outdoor temp', fontsize = 15)
plt.title('Outdoor Temp & Hour of Day', fontsize = 20)
plt.savefig("Figure11.png")
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot( data = df[df['Heat Stage 1 (sec)'] == 300], x = 'HourofDay', hue = 'Program Mode')
maxHeatUsage.set_xlabel('Hour Of Day', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 15)
plt.title('Heat Usage by Hour of Day & Program Mode', fontsize = 20)
plt.savefig("figure4.png")
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot( data = df[df['Heat Stage 1 (sec)'] == 300], x = 'DayOfWeek', hue = 'Program Mode')
maxHeatUsage.set_xlabel('Day Of Week', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 15)
plt.title('Heat Usage by Day Of Week & Program Mode', fontsize = 20)
plt.savefig("figure6.png")
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot( data = df[df['Heat Stage 1 (sec)'] == 300], x = 'HourofDay', hue = 'Thermostat Motion')
maxHeatUsage.set_xlabel('Hour of Day', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 15)
plt.title('Heat Usage by Hour of Day & Thermostat Motion', fontsize = 20)
plt.savefig("figure7.png")
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
maxHeatUsage = sns.countplot( data = df[df['Heat Stage 1 (sec)'] == 300], x = 'DayOfWeek', hue = 'Thermostat Motion')
maxHeatUsage.set_xlabel('Day Of Week', fontsize = 20)
maxHeatUsage.set_ylabel('# of Instances of Usafe of Heat Source for 300 Seconds', fontsize = 15)
plt.title('Heat Usage by Day Of Week & Thermostat Motion', fontsize = 20)
plt.savefig("figure8.png")
plt.show()

# %%
df.groupby(['Month']).agg(np.mean)
# Out:
#           Cool Set Temp (C)  Heat Set Temp (C)  Current Temp (C)  \
# Month
# December               21.0               21.0         20.820110
# February               21.0               21.0         20.840303
# January                21.0               21.0         20.822112
# March                  21.0               21.0         20.880583
#
#           Current Humidity (%RH)  Outdoor Temp (C)  Wind Speed (km/h)  \
# Month
# December               28.951307         -0.900226                0.0
# February               20.610249         -5.576711                0.0
# January                26.473342         -3.213038                0.0
# March                  21.871585          1.147462                0.0
#
#           Cool Stage 1 (sec)  Heat Stage 1 (sec)   Fan (sec)  \
# Month
# December                 0.0          115.084402  122.067035
# February                 0.0          120.070728  125.717831
# January                  0.0          114.938826  121.277921
# March                    0.0           80.718475   85.378916
#
#           Thermostat Temperature (C)  ...  Bedroom (C)  Bedroom2  \
# Month                                 ...
# December                   20.820110  ...    21.840464  0.001461
# February                   20.840303  ...    21.518762  0.001861
# January                    20.822112  ...    21.647772  0.000561
# March                      20.880583  ...    21.500262  0.008335
#
#           3rd floor landing (C)  3rd floor landing2  3rd floor room (C)  \
# Month
# December              20.837543            0.399448            20.89328
# February              20.638925            0.597220            20.58640
# January               20.668683            0.387137            20.70495
# March                 20.892854            0.180583            20.69537
#
#           3rd floor room2  Basement (C)  Basement2  HourofDay        Day
# Month
# December         0.000974     22.662068   0.015095  11.638952  20.761566
# February         0.001613     21.996426   0.014394  11.500000  14.500000
# January          0.003367     22.356157   0.015827  11.500000  16.000000
# March            0.000463     22.120960   0.023923  11.392187  11.810212
#
# [4 rows x 22 columns]

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
averageTemp = sns.barplot(x = df['Month'], y = df['Outdoor Temp (C)'], order = ['December','January','February','March'], color = 'steelblue')
averageTemp.set_xlabel('Month', fontsize = 20)
averageTemp.set_ylabel('Average Outdor Temp (degree C)', fontsize = 20)
plt.title('Average Outdoor Temperature by Month', fontsize = 20)
plt.savefig("figure9.png")
plt.show()

# %%
NG_Data = pd.read_excel('Cumulative_meter_NG_Data.xlsx')

# %%
NG_Data.head()
# Out:
#              Timestamp  Cumulative_meter  Ambient_temp_north_wall_C
# 0  2020-12-10 12:50:00          0.000000                   4.390761
# 1  2020-12-10 13:00:00          6.766667                   4.384753
# 2  2020-12-10 14:00:00         15.766667                   4.507190
# 3  2020-12-10 15:00:00         23.533333                   4.471141
# 4  2020-12-10 16:00:00         31.033333                   2.838034

# %%
NG_Data['Timestamp'] = pd.to_datetime(NG_Data['Timestamp'])

# %%
NG_Data['Month'] = pd.DatetimeIndex(NG_Data['Timestamp']).month

# %%
NG_Data.head()
# Out:
#             Timestamp  Cumulative_meter  Ambient_temp_north_wall_C  Month
# 0 2020-12-10 12:50:00          0.000000                   4.390761     12
# 1 2020-12-10 13:00:00          6.766667                   4.384753     12
# 2 2020-12-10 14:00:00         15.766667                   4.507190     12
# 3 2020-12-10 15:00:00         23.533333                   4.471141     12
# 4 2020-12-10 16:00:00         31.033333                   2.838034     12

# %%
for i in range(len(NG_Data)):
    if NG_Data['Month'][i] == 12:
        NG_Data['Month'][i] = 'December'
    elif NG_Data['Month'][i] == 1:
        NG_Data['Month'][i] = 'January'
    elif NG_Data['Month'][i] == 2:
        NG_Data['Month'][i] = 'February'
    else:
        NG_Data['Month'][i] = 'March'
# Out:
# <ipython-input-24-438b62c3f9d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NG_Data['Month'][i] = 'December'
# /Users/mac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-24-438b62c3f9d0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NG_Data['Month'][i] = 'January'
# <ipython-input-24-438b62c3f9d0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NG_Data['Month'][i] = 'February'
# <ipython-input-24-438b62c3f9d0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NG_Data['Month'][i] = 'March'

# %%
NG_Data.groupby(['Month']).agg(np.mean)
# Out:
#           Cumulative_meter  Ambient_temp_north_wall_C
# Month
# December       1886.961961                  -1.148361
# February       5067.386834                  -7.208202
# January        2627.015305                  -3.216220
# March         11468.734719                   0.996403

# %%
plt.figure(figsize = (15, 10))
sns.set_style('whitegrid')
averageTemp = sns.barplot(x = NG_Data['Month'], y = NG_Data['Ambient_temp_north_wall_C'], order = ['December','January','February','March'], color = 'steelblue')
averageTemp.set_xlabel('Month', fontsize = 20)
averageTemp.set_ylabel('Average Outdor Temp (degree C)', fontsize = 20)
plt.title('Average Outdoor Temperature by Month', fontsize = 20)
plt.show()
